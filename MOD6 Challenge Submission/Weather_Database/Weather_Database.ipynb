# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
lats = np.random.uniform(low=-90.000,high=90.000,size=2000)
lngs = np.random.uniform(low=-180.000,high=180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 746

# %%
import requests
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data2 = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_conditions = city_weather["weather"][0]["description"]
        #parsing array reference: https://devqa.io/python-parse-json/
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data2.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                           "Current Description": city_conditions,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 1 | longyearbyen
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | raudeberg
# Processing Record 6 of Set 1 | bredasdorp
# Processing Record 7 of Set 1 | shingu
# Processing Record 8 of Set 1 | jamestown
# Processing Record 9 of Set 1 | rikitea
# Processing Record 10 of Set 1 | vanavara
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | verkhnetulomskiy
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | luganville
# Processing Record 18 of Set 1 | jimo
# Processing Record 19 of Set 1 | zlatoustovsk
# City not found. Skipping...
# Processing Record 20 of Set 1 | zhigansk
# Processing Record 21 of Set 1 | comodoro rivadavia
# Processing Record 22 of Set 1 | greeneville
# Processing Record 23 of Set 1 | kondinskoye
# Processing Record 24 of Set 1 | thompson
# Processing Record 25 of Set 1 | gao
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | straumen
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | worthington
# Processing Record 30 of Set 1 | bathsheba
# Processing Record 31 of Set 1 | mataura
# Processing Record 32 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 33 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 1 | skibbereen
# Processing Record 35 of Set 1 | new norfolk
# Processing Record 36 of Set 1 | asau
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | mount gambier
# Processing Record 39 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 1 | sao filipe
# Processing Record 41 of Set 1 | georgetown
# Processing Record 42 of Set 1 | le port
# Processing Record 43 of Set 1 | osakarovka
# Processing Record 44 of Set 1 | tezu
# Processing Record 45 of Set 1 | port elizabeth
# Processing Record 46 of Set 1 | norman wells
# Processing Record 47 of Set 1 | chapais
# Processing Record 48 of Set 1 | port alfred
# Processing Record 49 of Set 1 | codrington
# Processing Record 50 of Set 1 | avera
# Processing Record 1 of Set 2 | surt
# Processing Record 2 of Set 2 | bethlehem
# Processing Record 3 of Set 2 | vestmannaeyjar
# Processing Record 4 of Set 2 | greytown
# Processing Record 5 of Set 2 | nyazepetrovsk
# Processing Record 6 of Set 2 | faanui
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | kiama
# Processing Record 9 of Set 2 | tasiilaq
# Processing Record 10 of Set 2 | ponta do sol
# Processing Record 11 of Set 2 | acapulco
# Processing Record 12 of Set 2 | bluff
# Processing Record 13 of Set 2 | kavaratti
# Processing Record 14 of Set 2 | maryborough
# Processing Record 15 of Set 2 | zeya
# Processing Record 16 of Set 2 | yinchuan
# Processing Record 17 of Set 2 | hermanus
# Processing Record 18 of Set 2 | wattegama
# Processing Record 19 of Set 2 | farmington
# Processing Record 20 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 2 | kaohsiung
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | pevek
# Processing Record 24 of Set 2 | buraydah
# Processing Record 25 of Set 2 | olinda
# Processing Record 26 of Set 2 | labuhan
# Processing Record 27 of Set 2 | kolyvan
# Processing Record 28 of Set 2 | touros
# Processing Record 29 of Set 2 | airai
# Processing Record 30 of Set 2 | zhanaozen
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | olafsvik
# Processing Record 34 of Set 2 | san patricio
# Processing Record 35 of Set 2 | kamyshla
# Processing Record 36 of Set 2 | puerto ayora
# Processing Record 37 of Set 2 | sitka
# Processing Record 38 of Set 2 | nemuro
# Processing Record 39 of Set 2 | tura
# Processing Record 40 of Set 2 | bujaru
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | rio grande
# Processing Record 43 of Set 2 | belize
# Processing Record 44 of Set 2 | kapaa
# Processing Record 45 of Set 2 | diapaga
# Processing Record 46 of Set 2 | zyryanka
# Processing Record 47 of Set 2 | cabo san lucas
# Processing Record 48 of Set 2 | guerrero negro
# Processing Record 49 of Set 2 | fortuna
# Processing Record 50 of Set 2 | castro
# Processing Record 1 of Set 3 | chokurdakh
# Processing Record 2 of Set 3 | torbay
# Processing Record 3 of Set 3 | saint-philippe
# Processing Record 4 of Set 3 | pyshchug
# Processing Record 5 of Set 3 | mar del plata
# Processing Record 6 of Set 3 | yenagoa
# Processing Record 7 of Set 3 | pesochnoye
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | palauig
# Processing Record 10 of Set 3 | revda
# Processing Record 11 of Set 3 | saskylakh
# Processing Record 12 of Set 3 | andijon
# Processing Record 13 of Set 3 | san carlos de bariloche
# Processing Record 14 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 15 of Set 3 | nago
# Processing Record 16 of Set 3 | byron bay
# Processing Record 17 of Set 3 | huilong
# Processing Record 18 of Set 3 | san cristobal
# Processing Record 19 of Set 3 | ilulissat
# Processing Record 20 of Set 3 | fare
# Processing Record 21 of Set 3 | thunder bay
# Processing Record 22 of Set 3 | vaini
# Processing Record 23 of Set 3 | sabha
# Processing Record 24 of Set 3 | rundu
# Processing Record 25 of Set 3 | johnstown
# Processing Record 26 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 27 of Set 3 | fomboni
# Processing Record 28 of Set 3 | virginia beach
# Processing Record 29 of Set 3 | presidencia roque saenz pena
# Processing Record 30 of Set 3 | westport
# Processing Record 31 of Set 3 | ramat yishay
# Processing Record 32 of Set 3 | bandarbeyla
# Processing Record 33 of Set 3 | butaritari
# Processing Record 34 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 36 of Set 3 | yerbogachen
# Processing Record 37 of Set 3 | hobart
# Processing Record 38 of Set 3 | cherskiy
# Processing Record 39 of Set 3 | ukiah
# Processing Record 40 of Set 3 | bethel
# Processing Record 41 of Set 3 | poum
# Processing Record 42 of Set 3 | chuy
# Processing Record 43 of Set 3 | srednekolymsk
# Processing Record 44 of Set 3 | huamachuco
# Processing Record 45 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 3 | hilo
# Processing Record 48 of Set 3 | upernavik
# Processing Record 49 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 50 of Set 3 | sarandi
# Processing Record 1 of Set 4 | sur
# Processing Record 2 of Set 4 | harrisburg
# Processing Record 3 of Set 4 | kaitangata
# Processing Record 4 of Set 4 | dimovo
# Processing Record 5 of Set 4 | korla
# Processing Record 6 of Set 4 | paltinis
# Processing Record 7 of Set 4 | sadon
# Processing Record 8 of Set 4 | longkou
# Processing Record 9 of Set 4 | mendi
# Processing Record 10 of Set 4 | culaman
# Processing Record 11 of Set 4 | galiakot
# Processing Record 12 of Set 4 | rosita
# Processing Record 13 of Set 4 | waipawa
# Processing Record 14 of Set 4 | sao joao da barra
# Processing Record 15 of Set 4 | aitape
# Processing Record 16 of Set 4 | hasaki
# Processing Record 17 of Set 4 | calbuco
# Processing Record 18 of Set 4 | saldanha
# Processing Record 19 of Set 4 | santa rosa
# Processing Record 20 of Set 4 | east london
# Processing Record 21 of Set 4 | raglan
# Processing Record 22 of Set 4 | tabarqah
# City not found. Skipping...
# Processing Record 23 of Set 4 | bairiki
# Processing Record 24 of Set 4 | san pedro
# Processing Record 25 of Set 4 | manacapuru
# Processing Record 26 of Set 4 | lodja
# Processing Record 27 of Set 4 | ribeira grande
# Processing Record 28 of Set 4 | nyandoma
# Processing Record 29 of Set 4 | bengkulu
# Processing Record 30 of Set 4 | clyde river
# Processing Record 31 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 4 | adrar
# Processing Record 33 of Set 4 | palaikastron
# Processing Record 34 of Set 4 | isabela
# Processing Record 35 of Set 4 | angoche
# Processing Record 36 of Set 4 | mahebourg
# Processing Record 37 of Set 4 | bambous virieux
# Processing Record 38 of Set 4 | weymouth
# Processing Record 39 of Set 4 | alofi
# Processing Record 40 of Set 4 | kavieng
# Processing Record 41 of Set 4 | tiksi
# Processing Record 42 of Set 4 | pangnirtung
# Processing Record 43 of Set 4 | karratha
# Processing Record 44 of Set 4 | wilmington
# Processing Record 45 of Set 4 | guanica
# Processing Record 46 of Set 4 | goba
# Processing Record 47 of Set 4 | portland
# Processing Record 48 of Set 4 | talnakh
# Processing Record 49 of Set 4 | lloydminster
# Processing Record 50 of Set 4 | vryburg
# Processing Record 1 of Set 5 | toropets
# Processing Record 2 of Set 5 | jining
# Processing Record 3 of Set 5 | vao
# Processing Record 4 of Set 5 | rivne
# Processing Record 5 of Set 5 | weligama
# Processing Record 6 of Set 5 | sisimiut
# Processing Record 7 of Set 5 | ossora
# Processing Record 8 of Set 5 | tunceli
# Processing Record 9 of Set 5 | tuatapere
# Processing Record 10 of Set 5 | coahuayana
# Processing Record 11 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 5 | rio gallegos
# Processing Record 13 of Set 5 | rawson
# Processing Record 14 of Set 5 | itarema
# Processing Record 15 of Set 5 | kamachumu
# Processing Record 16 of Set 5 | sumenep
# Processing Record 17 of Set 5 | nikolskoye
# Processing Record 18 of Set 5 | burnie
# Processing Record 19 of Set 5 | melilla
# Processing Record 20 of Set 5 | grindavik
# Processing Record 21 of Set 5 | fairbanks
# Processing Record 22 of Set 5 | georgiyevka
# Processing Record 23 of Set 5 | japura
# Processing Record 24 of Set 5 | durusu
# Processing Record 25 of Set 5 | birin
# Processing Record 26 of Set 5 | ternovka
# Processing Record 27 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 5 | sabang
# Processing Record 29 of Set 5 | mildura
# Processing Record 30 of Set 5 | erzin
# Processing Record 31 of Set 5 | atar
# Processing Record 32 of Set 5 | phan thiet
# Processing Record 33 of Set 5 | saint george
# Processing Record 34 of Set 5 | himora
# City not found. Skipping...
# Processing Record 35 of Set 5 | san felipe
# Processing Record 36 of Set 5 | onega
# Processing Record 37 of Set 5 | vanimo
# Processing Record 38 of Set 5 | salalah
# Processing Record 39 of Set 5 | deputatskiy
# Processing Record 40 of Set 5 | conde
# Processing Record 41 of Set 5 | villazon
# Processing Record 42 of Set 5 | abonnema
# Processing Record 43 of Set 5 | malatya
# Processing Record 44 of Set 5 | bekobod
# Processing Record 45 of Set 5 | kajansi
# Processing Record 46 of Set 5 | heihe
# Processing Record 47 of Set 5 | hami
# Processing Record 48 of Set 5 | san policarpo
# Processing Record 49 of Set 5 | lancaster
# Processing Record 50 of Set 5 | sokoni
# Processing Record 1 of Set 6 | mangrul pir
# Processing Record 2 of Set 6 | lebu
# Processing Record 3 of Set 6 | baruun-urt
# Processing Record 4 of Set 6 | tuy hoa
# Processing Record 5 of Set 6 | ribeira brava
# Processing Record 6 of Set 6 | oliveira dos brejinhos
# Processing Record 7 of Set 6 | fort nelson
# Processing Record 8 of Set 6 | ingham
# Processing Record 9 of Set 6 | nhulunbuy
# Processing Record 10 of Set 6 | kloulklubed
# Processing Record 11 of Set 6 | berlevag
# Processing Record 12 of Set 6 | pimentel
# Processing Record 13 of Set 6 | muros
# Processing Record 14 of Set 6 | alta floresta
# Processing Record 15 of Set 6 | cidreira
# Processing Record 16 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 6 | loreto
# Processing Record 18 of Set 6 | turukhansk
# Processing Record 19 of Set 6 | ixtapa
# Processing Record 20 of Set 6 | port hedland
# Processing Record 21 of Set 6 | padang
# Processing Record 22 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 6 | cap malheureux
# Processing Record 24 of Set 6 | maldonado
# Processing Record 25 of Set 6 | broken hill
# Processing Record 26 of Set 6 | sumbal
# Processing Record 27 of Set 6 | aloleng
# Processing Record 28 of Set 6 | nazare
# Processing Record 29 of Set 6 | isangel
# Processing Record 30 of Set 6 | la ronge
# Processing Record 31 of Set 6 | lasa
# Processing Record 32 of Set 6 | jinxi
# Processing Record 33 of Set 6 | port macquarie
# Processing Record 34 of Set 6 | lavrentiya
# Processing Record 35 of Set 6 | kutahya
# Processing Record 36 of Set 6 | concordia
# Processing Record 37 of Set 6 | biggar
# Processing Record 38 of Set 6 | araouane
# Processing Record 39 of Set 6 | vardo
# Processing Record 40 of Set 6 | hofn
# Processing Record 41 of Set 6 | bereznehuvate
# Processing Record 42 of Set 6 | semnan
# Processing Record 43 of Set 6 | mecca
# Processing Record 44 of Set 6 | margate
# Processing Record 45 of Set 6 | puerto cabezas
# Processing Record 46 of Set 6 | beian
# Processing Record 47 of Set 6 | igmaya-an
# Processing Record 48 of Set 6 | arlit
# Processing Record 49 of Set 6 | salinas
# Processing Record 50 of Set 6 | la paz
# Processing Record 1 of Set 7 | vaxjo
# Processing Record 2 of Set 7 | yabelo
# Processing Record 3 of Set 7 | los llanos de aridane
# Processing Record 4 of Set 7 | hede
# Processing Record 5 of Set 7 | porto velho
# Processing Record 6 of Set 7 | catuday
# Processing Record 7 of Set 7 | tautira
# Processing Record 8 of Set 7 | praia da vitoria
# Processing Record 9 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 7 | kahului
# Processing Record 11 of Set 7 | alice springs
# Processing Record 12 of Set 7 | osmena
# Processing Record 13 of Set 7 | dikson
# Processing Record 14 of Set 7 | yar-sale
# Processing Record 15 of Set 7 | big spring
# Processing Record 16 of Set 7 | sept-iles
# Processing Record 17 of Set 7 | inhambane
# Processing Record 18 of Set 7 | ulladulla
# Processing Record 19 of Set 7 | kapuskasing
# Processing Record 20 of Set 7 | oruro
# Processing Record 21 of Set 7 | matara
# Processing Record 22 of Set 7 | iquique
# Processing Record 23 of Set 7 | port angeles
# Processing Record 24 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 7 | sommerda
# Processing Record 26 of Set 7 | wucheng
# Processing Record 27 of Set 7 | qasigiannguit
# Processing Record 28 of Set 7 | kanigoro
# Processing Record 29 of Set 7 | pangai
# Processing Record 30 of Set 7 | tailai
# Processing Record 31 of Set 7 | roebourne
# Processing Record 32 of Set 7 | zaysan
# Processing Record 33 of Set 7 | laguna
# Processing Record 34 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 35 of Set 7 | saint-augustin
# Processing Record 36 of Set 7 | bowen
# Processing Record 37 of Set 7 | olbia
# Processing Record 38 of Set 7 | morgantown
# Processing Record 39 of Set 7 | russell
# Processing Record 40 of Set 7 | casper
# Processing Record 41 of Set 7 | wajid
# Processing Record 42 of Set 7 | lagoa
# Processing Record 43 of Set 7 | dingle
# Processing Record 44 of Set 7 | melong
# Processing Record 45 of Set 7 | manaquiri
# Processing Record 46 of Set 7 | aberlour
# City not found. Skipping...
# Processing Record 47 of Set 7 | chimore
# Processing Record 48 of Set 7 | nuuk
# Processing Record 49 of Set 7 | fayaoue
# Processing Record 50 of Set 7 | petrokamenskoye
# Processing Record 1 of Set 8 | ouesso
# Processing Record 2 of Set 8 | riberalta
# Processing Record 3 of Set 8 | guatire
# Processing Record 4 of Set 8 | pisco
# Processing Record 5 of Set 8 | tateyama
# Processing Record 6 of Set 8 | xiongzhou
# Processing Record 7 of Set 8 | mollendo
# Processing Record 8 of Set 8 | husavik
# Processing Record 9 of Set 8 | mount isa
# Processing Record 10 of Set 8 | sibut
# Processing Record 11 of Set 8 | richards bay
# Processing Record 12 of Set 8 | tual
# Processing Record 13 of Set 8 | gorontalo
# Processing Record 14 of Set 8 | piracuruca
# Processing Record 15 of Set 8 | narsaq
# Processing Record 16 of Set 8 | ayan
# Processing Record 17 of Set 8 | gushikawa
# Processing Record 18 of Set 8 | the valley
# Processing Record 19 of Set 8 | naifaru
# Processing Record 20 of Set 8 | sovetskiy
# Processing Record 21 of Set 8 | tahmek
# Processing Record 22 of Set 8 | uvalde
# Processing Record 23 of Set 8 | padre paraiso
# Processing Record 24 of Set 8 | ust-omchug
# Processing Record 25 of Set 8 | mosjoen
# Processing Record 26 of Set 8 | severo-yeniseyskiy
# Processing Record 27 of Set 8 | azangaro
# Processing Record 28 of Set 8 | brigantine
# Processing Record 29 of Set 8 | burica
# City not found. Skipping...
# Processing Record 30 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 31 of Set 8 | vulcan
# Processing Record 32 of Set 8 | omsukchan
# Processing Record 33 of Set 8 | nagar karnul
# Processing Record 34 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 8 | klaksvik
# Processing Record 36 of Set 8 | ewo
# Processing Record 37 of Set 8 | balabac
# Processing Record 38 of Set 8 | ancud
# Processing Record 39 of Set 8 | vinh
# Processing Record 40 of Set 8 | kirakira
# Processing Record 41 of Set 8 | kuusamo
# Processing Record 42 of Set 8 | kruisfontein
# Processing Record 43 of Set 8 | naze
# Processing Record 44 of Set 8 | vanderhoof
# Processing Record 45 of Set 8 | provideniya
# Processing Record 46 of Set 8 | beloha
# Processing Record 47 of Set 8 | masloc
# Processing Record 48 of Set 8 | rocha
# Processing Record 49 of Set 8 | mutoko
# Processing Record 50 of Set 8 | brae
# Processing Record 1 of Set 9 | saint-pierre
# Processing Record 2 of Set 9 | sambava
# Processing Record 3 of Set 9 | hamilton
# Processing Record 4 of Set 9 | mineiros
# Processing Record 5 of Set 9 | shenjiamen
# Processing Record 6 of Set 9 | najran
# Processing Record 7 of Set 9 | payo
# Processing Record 8 of Set 9 | aberdeen
# Processing Record 9 of Set 9 | cavalcante
# Processing Record 10 of Set 9 | diego de almagro
# Processing Record 11 of Set 9 | baisha
# Processing Record 12 of Set 9 | gornopravdinsk
# Processing Record 13 of Set 9 | severo-kurilsk
# Processing Record 14 of Set 9 | esperance
# Processing Record 15 of Set 9 | makung
# City not found. Skipping...
# Processing Record 16 of Set 9 | upata
# Processing Record 17 of Set 9 | nkoteng
# Processing Record 18 of Set 9 | kholmogory
# Processing Record 19 of Set 9 | gizo
# Processing Record 20 of Set 9 | lahij
# Processing Record 21 of Set 9 | taoudenni
# Processing Record 22 of Set 9 | beringovskiy
# Processing Record 23 of Set 9 | afgoye
# City not found. Skipping...
# Processing Record 24 of Set 9 | arica
# Processing Record 25 of Set 9 | ikom
# Processing Record 26 of Set 9 | gorham
# Processing Record 27 of Set 9 | larsnes
# Processing Record 28 of Set 9 | pontianak
# Processing Record 29 of Set 9 | khatanga
# Processing Record 30 of Set 9 | geraldton
# Processing Record 31 of Set 9 | schwalmstadt
# Processing Record 32 of Set 9 | kurumkan
# Processing Record 33 of Set 9 | krasnoselkup
# Processing Record 34 of Set 9 | tillabery
# City not found. Skipping...
# Processing Record 35 of Set 9 | pangani
# Processing Record 36 of Set 9 | denpasar
# Processing Record 37 of Set 9 | mezen
# Processing Record 38 of Set 9 | atambua
# Processing Record 39 of Set 9 | kalomo
# City not found. Skipping...
# Processing Record 40 of Set 9 | nara
# Processing Record 41 of Set 9 | broome
# Processing Record 42 of Set 9 | santa cruz cabralia
# Processing Record 43 of Set 9 | adamovka
# Processing Record 44 of Set 9 | moose factory
# Processing Record 45 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 46 of Set 9 | lima
# Processing Record 47 of Set 9 | shimanovsk
# Processing Record 48 of Set 9 | roald
# Processing Record 49 of Set 9 | elmadag
# Processing Record 50 of Set 9 | astana
# Processing Record 1 of Set 10 | auki
# Processing Record 2 of Set 10 | goundam
# Processing Record 3 of Set 10 | chancay
# Processing Record 4 of Set 10 | oildale
# Processing Record 5 of Set 10 | scarborough
# Processing Record 6 of Set 10 | zaozerne
# Processing Record 7 of Set 10 | champasak
# Processing Record 8 of Set 10 | kushmurun
# Processing Record 9 of Set 10 | hervey bay
# Processing Record 10 of Set 10 | henties bay
# Processing Record 11 of Set 10 | hovd
# Processing Record 12 of Set 10 | vaitape
# Processing Record 13 of Set 10 | ullapool
# Processing Record 14 of Set 10 | zhigalovo
# Processing Record 15 of Set 10 | tucumcari
# Processing Record 16 of Set 10 | marienburg
# Processing Record 17 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 10 | namibe
# Processing Record 19 of Set 10 | grand gaube
# Processing Record 20 of Set 10 | hobyo
# Processing Record 21 of Set 10 | manitouwadge
# Processing Record 22 of Set 10 | mehran
# Processing Record 23 of Set 10 | katobu
# Processing Record 24 of Set 10 | lorengau
# Processing Record 25 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 10 | barmer
# Processing Record 27 of Set 10 | gamba
# Processing Record 28 of Set 10 | nanortalik
# Processing Record 29 of Set 10 | kasongo-lunda
# Processing Record 30 of Set 10 | flensburg
# Processing Record 31 of Set 10 | williams lake
# Processing Record 32 of Set 10 | brownsville
# Processing Record 33 of Set 10 | ostrovnoy
# Processing Record 34 of Set 10 | necochea
# Processing Record 35 of Set 10 | faya
# Processing Record 36 of Set 10 | sorland
# Processing Record 37 of Set 10 | launceston
# Processing Record 38 of Set 10 | killybegs
# Processing Record 39 of Set 10 | makakilo city
# Processing Record 40 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 41 of Set 10 | nouadhibou
# Processing Record 42 of Set 10 | artyk
# City not found. Skipping...
# Processing Record 43 of Set 10 | port blair
# Processing Record 44 of Set 10 | erenhot
# Processing Record 45 of Set 10 | belfast
# Processing Record 46 of Set 10 | seymchan
# Processing Record 47 of Set 10 | reconquista
# Processing Record 48 of Set 10 | kijang
# Processing Record 49 of Set 10 | gojo
# Processing Record 50 of Set 10 | pacific grove
# Processing Record 1 of Set 11 | la maddalena
# Processing Record 2 of Set 11 | thinadhoo
# Processing Record 3 of Set 11 | prokudskoye
# Processing Record 4 of Set 11 | cayenne
# Processing Record 5 of Set 11 | southbury
# Processing Record 6 of Set 11 | paamiut
# Processing Record 7 of Set 11 | luderitz
# Processing Record 8 of Set 11 | grand-santi
# Processing Record 9 of Set 11 | damietta
# Processing Record 10 of Set 11 | monrovia
# Processing Record 11 of Set 11 | kamenka
# Processing Record 12 of Set 11 | bandar-e anzali
# Processing Record 13 of Set 11 | innisfail
# Processing Record 14 of Set 11 | vila velha
# Processing Record 15 of Set 11 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 16 of Set 11 | pochutla
# Processing Record 17 of Set 11 | aldergrove
# Processing Record 18 of Set 11 | nishihara
# Processing Record 19 of Set 11 | matadi
# Processing Record 20 of Set 11 | belmonte
# Processing Record 21 of Set 11 | rio bueno
# Processing Record 22 of Set 11 | atasu
# Processing Record 23 of Set 11 | teahupoo
# Processing Record 24 of Set 11 | gold coast
# Processing Record 25 of Set 11 | gambo
# Processing Record 26 of Set 11 | zonnebeke
# Processing Record 27 of Set 11 | tamiahua
# Processing Record 28 of Set 11 | rogun
# City not found. Skipping...
# Processing Record 29 of Set 11 | lang son
# Processing Record 30 of Set 11 | coihaique
# Processing Record 31 of Set 11 | barbar
# City not found. Skipping...
# Processing Record 32 of Set 11 | svetlogorsk
# Processing Record 33 of Set 11 | lamar
# Processing Record 34 of Set 11 | gat
# Processing Record 35 of Set 11 | soyo
# Processing Record 36 of Set 11 | bethanien
# Processing Record 37 of Set 11 | seydisehir
# Processing Record 38 of Set 11 | muravlenko
# Processing Record 39 of Set 11 | lompoc
# Processing Record 40 of Set 11 | homer
# Processing Record 41 of Set 11 | cedar city
# Processing Record 42 of Set 11 | guadalajara
# Processing Record 43 of Set 11 | quelimane
# Processing Record 44 of Set 11 | pangody
# Processing Record 45 of Set 11 | labytnangi
# Processing Record 46 of Set 11 | leningradskiy
# Processing Record 47 of Set 11 | kissidougou
# Processing Record 48 of Set 11 | trapani
# Processing Record 49 of Set 11 | mehamn
# Processing Record 50 of Set 11 | neuquen
# Processing Record 1 of Set 12 | stellenbosch
# Processing Record 2 of Set 12 | zhuzhou
# Processing Record 3 of Set 12 | abbotsford
# Processing Record 4 of Set 12 | surin
# Processing Record 5 of Set 12 | parabel
# Processing Record 6 of Set 12 | nome
# Processing Record 7 of Set 12 | banda aceh
# Processing Record 8 of Set 12 | usinsk
# Processing Record 9 of Set 12 | medicine hat
# Processing Record 10 of Set 12 | halifax
# Processing Record 11 of Set 12 | kununurra
# Processing Record 12 of Set 12 | half moon bay
# Processing Record 13 of Set 12 | balsas
# Processing Record 14 of Set 12 | hay river
# Processing Record 15 of Set 12 | beidao
# Processing Record 16 of Set 12 | kinston
# Processing Record 17 of Set 12 | port lincoln
# Processing Record 18 of Set 12 | boyolangu
# Processing Record 19 of Set 12 | coos bay
# Processing Record 20 of Set 12 | cancun
# Processing Record 21 of Set 12 | ankazoabo
# Processing Record 22 of Set 12 | san quintin
# Processing Record 23 of Set 12 | samarai
# Processing Record 24 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 12 | mariakani
# Processing Record 26 of Set 12 | kaitong
# Processing Record 27 of Set 12 | aras
# Processing Record 28 of Set 12 | entre rios
# Processing Record 29 of Set 12 | abu samrah
# Processing Record 30 of Set 12 | mogadishu
# Processing Record 31 of Set 12 | walvis bay
# Processing Record 32 of Set 12 | yantal
# Processing Record 33 of Set 12 | wukari
# Processing Record 34 of Set 12 | buala
# Processing Record 35 of Set 12 | cabimas
# Processing Record 36 of Set 12 | ginir
# Processing Record 37 of Set 12 | cartagena
# Processing Record 38 of Set 12 | tome-acu
# City not found. Skipping...
# Processing Record 39 of Set 12 | yuzhnyy
# Processing Record 40 of Set 12 | tilichiki
# Processing Record 41 of Set 12 | la palma
# Processing Record 42 of Set 12 | jiaojiang
# Processing Record 43 of Set 12 | vostok
# Processing Record 44 of Set 12 | ozgon
# City not found. Skipping...
# Processing Record 45 of Set 12 | uyuni
# Processing Record 46 of Set 12 | coquimbo
# Processing Record 47 of Set 12 | lembeni
# Processing Record 48 of Set 12 | wildeshausen
# Processing Record 49 of Set 12 | khed brahma
# Processing Record 50 of Set 12 | sembabule
# Processing Record 1 of Set 13 | ola
# Processing Record 2 of Set 13 | donauworth
# Processing Record 3 of Set 13 | sinnamary
# Processing Record 4 of Set 13 | rovaniemi
# Processing Record 5 of Set 13 | shakhtinsk
# Processing Record 6 of Set 13 | machilipatnam
# Processing Record 7 of Set 13 | lazurne
# Processing Record 8 of Set 13 | lata
# Processing Record 9 of Set 13 | umm bab
# Processing Record 10 of Set 13 | bud
# Processing Record 11 of Set 13 | rabaul
# Processing Record 12 of Set 13 | vincennes
# Processing Record 13 of Set 13 | stoyba
# City not found. Skipping...
# Processing Record 14 of Set 13 | port hardy
# Processing Record 15 of Set 13 | kharsawan
# Processing Record 16 of Set 13 | waw
# Processing Record 17 of Set 13 | bilma
# Processing Record 18 of Set 13 | kupang
# Processing Record 19 of Set 13 | nova olimpia
# Processing Record 20 of Set 13 | talcahuano
# Processing Record 21 of Set 13 | mayo
# Processing Record 22 of Set 13 | aranos
# Processing Record 23 of Set 13 | evensk
# Processing Record 24 of Set 13 | atlantic beach
# Processing Record 25 of Set 13 | daru
# Processing Record 26 of Set 13 | okhotsk
# Processing Record 27 of Set 13 | oyama
# Processing Record 28 of Set 13 | belokurikha
# Processing Record 29 of Set 13 | harper
# Processing Record 30 of Set 13 | ituni
# City not found. Skipping...
# Processing Record 31 of Set 13 | formosa
# Processing Record 32 of Set 13 | grodkow
# Processing Record 33 of Set 13 | sterling
# Processing Record 34 of Set 13 | bilibino
# Processing Record 35 of Set 13 | diamantino
# Processing Record 36 of Set 13 | marsh harbour
# Processing Record 37 of Set 13 | acarau
# Processing Record 38 of Set 13 | vallenar
# Processing Record 39 of Set 13 | mana
# Processing Record 40 of Set 13 | sorsk
# Processing Record 41 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 42 of Set 13 | ponta pora
# Processing Record 43 of Set 13 | victoria
# Processing Record 44 of Set 13 | madras
# Processing Record 45 of Set 13 | makasar
# Processing Record 46 of Set 13 | nha trang
# Processing Record 47 of Set 13 | kanashevo
# Processing Record 48 of Set 13 | plettenberg bay
# Processing Record 49 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 50 of Set 13 | zhanatas
# City not found. Skipping...
# Processing Record 1 of Set 14 | san jeronimo
# Processing Record 2 of Set 14 | nadym
# Processing Record 3 of Set 14 | namatanai
# Processing Record 4 of Set 14 | achutupo
# Processing Record 5 of Set 14 | caravelas
# Processing Record 6 of Set 14 | manaus
# Processing Record 7 of Set 14 | puerto quijarro
# Processing Record 8 of Set 14 | puksoozero
# Processing Record 9 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 10 of Set 14 | gewane
# Processing Record 11 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 14 | filimonovo
# Processing Record 13 of Set 14 | komsomolskiy
# Processing Record 14 of Set 14 | umm lajj
# Processing Record 15 of Set 14 | camana
# Processing Record 16 of Set 14 | manzil salim
# Processing Record 17 of Set 14 | zambezi
# Processing Record 18 of Set 14 | filotion
# Processing Record 19 of Set 14 | kudahuvadhoo
# Processing Record 20 of Set 14 | havoysund
# Processing Record 21 of Set 14 | high level
# Processing Record 22 of Set 14 | cabedelo
# Processing Record 23 of Set 14 | port moresby
# Processing Record 24 of Set 14 | hirara
# Processing Record 25 of Set 14 | madimba
# Processing Record 26 of Set 14 | ahipara
# Processing Record 27 of Set 14 | grand forks
# Processing Record 28 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 14 | sola
# Processing Record 30 of Set 14 | taonan
# Processing Record 31 of Set 14 | iqaluit
# Processing Record 32 of Set 14 | puerto del rosario
# Processing Record 33 of Set 14 | uvat
# Processing Record 34 of Set 14 | tucurui
# Processing Record 35 of Set 14 | serenje
# Processing Record 36 of Set 14 | kysyl-syr
# Processing Record 37 of Set 14 | passos
# Processing Record 38 of Set 14 | banjar
# Processing Record 39 of Set 14 | loten
# Processing Record 40 of Set 14 | wajima
# Processing Record 41 of Set 14 | shirvan
# Processing Record 42 of Set 14 | xai-xai
# Processing Record 43 of Set 14 | kirkenaer
# Processing Record 44 of Set 14 | ust-nera
# Processing Record 45 of Set 14 | gwanda
# Processing Record 46 of Set 14 | goderich
# Processing Record 47 of Set 14 | mentok
# City not found. Skipping...
# Processing Record 48 of Set 14 | tomatlan
# Processing Record 49 of Set 14 | prince george
# Processing Record 50 of Set 14 | myanaung
# Processing Record 1 of Set 15 | guerrero
# Processing Record 2 of Set 15 | wellington
# Processing Record 3 of Set 15 | kaeo
# Processing Record 4 of Set 15 | souillac
# Processing Record 5 of Set 15 | kosa
# Processing Record 6 of Set 15 | karauzyak
# City not found. Skipping...
# Processing Record 7 of Set 15 | hoa binh
# Processing Record 8 of Set 15 | baoning
# Processing Record 9 of Set 15 | zima
# Processing Record 10 of Set 15 | luebo
# Processing Record 11 of Set 15 | sao jose da coroa grande
# Processing Record 12 of Set 15 | yeniseysk
# Processing Record 13 of Set 15 | padilla
# Processing Record 14 of Set 15 | oxford
# Processing Record 15 of Set 15 | rayong
# Processing Record 16 of Set 15 | nantucket
# Processing Record 17 of Set 15 | povenets
# Processing Record 18 of Set 15 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 15 | harmanli
# Processing Record 20 of Set 15 | guanare
# Processing Record 21 of Set 15 | murighiol
# Processing Record 22 of Set 15 | khartoum
# Processing Record 23 of Set 15 | masterton
# Processing Record 24 of Set 15 | bonavista
# Processing Record 25 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 26 of Set 15 | manavalakurichi
# Processing Record 27 of Set 15 | jinka
# Processing Record 28 of Set 15 | sungaipenuh
# Processing Record 29 of Set 15 | gobabis
# Processing Record 30 of Set 15 | queenstown
# Processing Record 31 of Set 15 | benguela
# Processing Record 32 of Set 15 | aklavik
# Processing Record 33 of Set 15 | ponta delgada
# Processing Record 34 of Set 15 | abaete
# Processing Record 35 of Set 15 | birobidzhan
# Processing Record 36 of Set 15 | owando
# Processing Record 37 of Set 15 | ippy
# Processing Record 38 of Set 15 | bontang
# Processing Record 39 of Set 15 | urulga
# City not found. Skipping...
# Processing Record 40 of Set 15 | san jose
# Processing Record 41 of Set 15 | winslow
# Processing Record 42 of Set 15 | garowe
# Processing Record 43 of Set 15 | malwan
# City not found. Skipping...
# Processing Record 44 of Set 15 | victor harbor
# Processing Record 45 of Set 15 | yashkino
# Processing Record 46 of Set 15 | lokosovo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data2))
# Out:
# 690

# %%
city_data2
# Out:
# [{'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.03,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 78.33,
#   'Humidity': 77,
#   'Cloudiness': 91,
#   'Wind Speed': 16.28,
#   'Country': 'PF'},
#  {'City': 'Longyearbyen',
#   'Lat': 78.22,
#   'Lng': 15.64,
#   'Current Description': 'snow',
#   'Max Temp': 28.4,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 47.2,
#   'Country': 'SJ'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.33,
#   'Current Description': 'clear sky',
#   'Max Temp': 80.01,
#   'Humidity': 40,
#   'Cloudiness': 0,
#   'Wind Speed': 8.01,
#   'Country': 'AU'},
#  {'City': 'Raudeberg',
#   'Lat': 61.99,
#   'Lng': 5.14,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 30.2,
#   'Humidity': 74,
#   'Cloudiness': 91,
#   'Wind Speed': 9.17,
#   'Country': 'NO'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.53,
#   'Lng': 20.04,
#   'Current Description': 'light rain',
#   'Max Temp': 69.8,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'ZA'},
#  {'City': 'Shingu',
#   'Lat': 33.73,
#   'Lng': 135.98,
#   'Current Description': 'broken clouds',
#   'Max Temp': 46.4,
#   'Humidity': 49,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'JP'},
#  {'City': 'Jamestown',
#   'Lat': 42.1,
#   'Lng': -79.24,
#   'Current Description': 'mist',
#   'Max Temp': 33.01,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'US'},
#  {'City': 'Rikitea',
#   'Lat': -23.12,
#   'Lng': -134.97,
#   'Current Description': 'few clouds',
#   'Max Temp': 76.89,
#   'Humidity': 73,
#   'Cloudiness': 12,
#   'Wind Speed': 17.11,
#   'Country': 'PF'},
#  {'City': 'Vanavara',
#   'Lat': 60.34,
#   'Lng': 102.28,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -27.4,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 7.72,
#   'Country': 'RU'},
#  {'City': 'Avarua',
#   'Lat': -21.21,
#   'Lng': -159.78,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 84.2,
#   'Humidity': 70,
#   'Cloudiness': 39,
#   'Wind Speed': 14.99,
#   'Country': 'CK'},
#  {'City': 'Verkhnetulomskiy',
#   'Lat': 68.61,
#   'Lng': 31.8,
#   'Current Description': 'clear sky',
#   'Max Temp': -5.8,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'RU'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.92,
#   'Current Description': 'broken clouds',
#   'Max Temp': 51.8,
#   'Humidity': 53,
#   'Cloudiness': 56,
#   'Wind Speed': 16.11,
#   'Country': 'CL'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Current Description': 'broken clouds',
#   'Max Temp': 51.8,
#   'Humidity': 53,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'AR'},
#  {'City': 'Yellowknife',
#   'Lat': 62.46,
#   'Lng': -114.35,
#   'Current Description': 'few clouds',
#   'Max Temp': -24,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'CA'},
#  {'City': 'Luganville',
#   'Lat': -15.53,
#   'Lng': 167.17,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 85.89,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 3.02,
#   'Country': 'VU'},
#  {'City': 'Jimo',
#   'Lat': 36.39,
#   'Lng': 120.46,
#   'Current Description': 'clear sky',
#   'Max Temp': 32,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 17.9,
#   'Country': 'CN'},
#  {'City': 'Zhigansk',
#   'Lat': 66.77,
#   'Lng': 123.37,
#   'Current Description': 'broken clouds',
#   'Max Temp': -40.2,
#   'Humidity': 80,
#   'Cloudiness': 68,
#   'Wind Speed': 8.25,
#   'Country': 'RU'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.87,
#   'Lng': -67.5,
#   'Current Description': 'clear sky',
#   'Max Temp': 57.2,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 12.75,
#   'Country': 'AR'},
#  {'City': 'Greeneville',
#   'Lat': 36.16,
#   'Lng': -82.83,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 41,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 3.11,
#   'Country': 'US'},
#  {'City': 'Kondinskoye',
#   'Lat': 59.65,
#   'Lng': 67.41,
#   'Current Description': 'broken clouds',
#   'Max Temp': -15.07,
#   'Humidity': 88,
#   'Cloudiness': 66,
#   'Wind Speed': 7.47,
#   'Country': 'RU'},
#  {'City': 'Thompson',
#   'Lat': 55.74,
#   'Lng': -97.86,
#   'Current Description': 'light snow',
#   'Max Temp': -0.4,
#   'Humidity': 84,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Country': 'CA'},
#  {'City': 'Gao',
#   'Lat': 16.64,
#   'Lng': 1.64,
#   'Current Description': 'clear sky',
#   'Max Temp': 71.49,
#   'Humidity': 22,
#   'Cloudiness': 0,
#   'Wind Speed': 7.72,
#   'Country': 'ML'},
#  {'City': 'Tuktoyaktuk',
#   'Lat': 69.45,
#   'Lng': -133.04,
#   'Current Description': 'broken clouds',
#   'Max Temp': -16.6,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'CA'},
#  {'City': 'Straumen',
#   'Lat': 63.87,
#   'Lng': 11.3,
#   'Current Description': 'clear sky',
#   'Max Temp': 30,
#   'Humidity': 85,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'NO'},
#  {'City': 'Barrow',
#   'Lat': 71.29,
#   'Lng': -156.79,
#   'Current Description': 'mist',
#   'Max Temp': -18.4,
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'US'},
#  {'City': 'Worthington',
#   'Lat': 40.09,
#   'Lng': -83.02,
#   'Current Description': 'few clouds',
#   'Max Temp': 30.99,
#   'Humidity': 92,
#   'Cloudiness': 20,
#   'Wind Speed': 3.49,
#   'Country': 'US'},
#  {'City': 'Bathsheba',
#   'Lat': 13.22,
#   'Lng': -59.52,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'BB'},
#  {'City': 'Mataura',
#   'Lat': -46.19,
#   'Lng': 168.86,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 55.45,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 1.52,
#   'Country': 'NZ'},
#  {'City': 'Skibbereen',
#   'Lat': 51.55,
#   'Lng': -9.27,
#   'Current Description': 'broken clouds',
#   'Max Temp': 35.6,
#   'Humidity': 90,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'IE'},
#  {'City': 'New Norfolk',
#   'Lat': -42.78,
#   'Lng': 147.06,
#   'Current Description': 'broken clouds',
#   'Max Temp': 71.01,
#   'Humidity': 46,
#   'Cloudiness': 76,
#   'Wind Speed': 1.01,
#   'Country': 'AU'},
#  {'City': 'Asau',
#   'Lat': 46.43,
#   'Lng': 26.4,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 43,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 6.82,
#   'Country': 'RO'},
#  {'City': 'Albany',
#   'Lat': 42.6,
#   'Lng': -73.97,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 34,
#   'Humidity': 87,
#   'Cloudiness': 96,
#   'Wind Speed': 2.39,
#   'Country': 'US'},
#  {'City': 'Mount Gambier',
#   'Lat': -37.83,
#   'Lng': 140.77,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 62.6,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 17.22,
#   'Country': 'AU'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.9,
#   'Lng': -24.5,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 74.77,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 0.63,
#   'Country': 'CV'},
#  {'City': 'Georgetown',
#   'Lat': 5.41,
#   'Lng': 100.34,
#   'Current Description': 'few clouds',
#   'Max Temp': 82.99,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'MY'},
#  {'City': 'Le Port',
#   'Lat': -20.94,
#   'Lng': 55.29,
#   'Current Description': 'light rain',
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Country': 'RE'},
#  {'City': 'Osakarovka',
#   'Lat': 50.56,
#   'Lng': 72.57,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -0.67,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 20.04,
#   'Country': 'KZ'},
#  {'City': 'Tezu',
#   'Lat': 27.92,
#   'Lng': 96.17,
#   'Current Description': 'clear sky',
#   'Max Temp': 72.28,
#   'Humidity': 24,
#   'Cloudiness': 7,
#   'Wind Speed': 2.01,
#   'Country': 'IN'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.92,
#   'Lng': 25.57,
#   'Current Description': 'light intensity drizzle',
#   'Max Temp': 73.4,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'ZA'},
#  {'City': 'Norman Wells',
#   'Lat': 65.28,
#   'Lng': -126.83,
#   'Current Description': 'few clouds',
#   'Max Temp': -7.6,
#   'Humidity': 63,
#   'Cloudiness': 20,
#   'Wind Speed': 23.04,
#   'Country': 'CA'},
#  {'City': 'Chapais',
#   'Lat': 49.78,
#   'Lng': -74.85,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 19.4,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Country': 'CA'},
#  {'City': 'Port Alfred',
#   'Lat': -33.59,
#   'Lng': 26.89,
#   'Current Description': 'broken clouds',
#   'Max Temp': 73.99,
#   'Humidity': 95,
#   'Cloudiness': 66,
#   'Wind Speed': 1.99,
#   'Country': 'ZA'},
#  {'City': 'Codrington',
#   'Lat': -38.27,
#   'Lng': 141.97,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 58.46,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 16.26,
#   'Country': 'AU'},
#  {'City': 'Avera',
#   'Lat': 33.19,
#   'Lng': -82.53,
#   'Current Description': 'clear sky',
#   'Max Temp': 42.8,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 7.34,
#   'Country': 'US'},
#  {'City': 'Surt',
#   'Lat': 31.21,
#   'Lng': 16.59,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 53.89,
#   'Humidity': 45,
#   'Cloudiness': 95,
#   'Wind Speed': 5.26,
#   'Country': 'LY'},
#  {'City': 'Bethlehem',
#   'Lat': -1.46,
#   'Lng': -48.5,
#   'Current Description': 'clear sky',
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'BR'},
#  {'City': 'Vestmannaeyjar',
#   'Lat': 63.44,
#   'Lng': -20.27,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 38.89,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 7.76,
#   'Country': 'IS'},
#  {'City': 'Greytown',
#   'Lat': -29.06,
#   'Lng': 30.59,
#   'Current Description': 'light rain',
#   'Max Temp': 63.81,
#   'Humidity': 97,
#   'Cloudiness': 99,
#   'Wind Speed': 2.26,
#   'Country': 'ZA'},
#  {'City': 'Nyazepetrovsk',
#   'Lat': 56.05,
#   'Lng': 59.6,
#   'Current Description': 'light snow',
#   'Max Temp': 6.24,
#   'Humidity': 94,
#   'Cloudiness': 93,
#   'Wind Speed': 2.86,
#   'Country': 'RU'},
#  {'City': 'Faanui',
#   'Lat': -16.48,
#   'Lng': -151.75,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 81.19,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 17.54,
#   'Country': 'PF'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.48,
#   'Lng': -69.36,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -1.82,
#   'Humidity': 76,
#   'Cloudiness': 96,
#   'Wind Speed': 4.29,
#   'Country': 'GL'},
#  {'City': 'Kiama',
#   'Lat': -34.68,
#   'Lng': 150.87,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 78.01,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'AU'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.61,
#   'Lng': -37.64,
#   'Current Description': 'clear sky',
#   'Max Temp': 17.6,
#   'Humidity': 57,
#   'Cloudiness': 1,
#   'Wind Speed': 2.24,
#   'Country': 'GL'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.67,
#   'Lng': -17.1,
#   'Current Description': 'light intensity shower rain',
#   'Max Temp': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 14.99,
#   'Country': 'PT'},
#  {'City': 'Acapulco',
#   'Lat': 16.86,
#   'Lng': -99.89,
#   'Current Description': 'clear sky',
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 5,
#   'Wind Speed': 3.36,
#   'Country': 'MX'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.33,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 54.1,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 4.29,
#   'Country': 'NZ'},
#  {'City': 'Kavaratti',
#   'Lat': 10.57,
#   'Lng': 72.64,
#   'Current Description': 'moderate rain',
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'IN'},
#  {'City': 'Maryborough',
#   'Lat': -25.53,
#   'Lng': 152.7,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 91.09,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind Speed': 6.89,
#   'Country': 'AU'},
#  {'City': 'Zeya',
#   'Lat': 53.75,
#   'Lng': 127.27,
#   'Current Description': 'clear sky',
#   'Max Temp': -14.17,
#   'Humidity': 75,
#   'Cloudiness': 5,
#   'Wind Speed': 1.03,
#   'Country': 'RU'},
#  {'City': 'Yinchuan',
#   'Lat': 38.47,
#   'Lng': 106.27,
#   'Current Description': 'clear sky',
#   'Max Temp': 15.35,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 2.39,
#   'Country': 'CN'},
#  {'City': 'Hermanus',
#   'Lat': -34.42,
#   'Lng': 19.23,
#   'Current Description': 'light rain',
#   'Max Temp': 70,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'ZA'},
#  {'City': 'Wattegama',
#   'Lat': 6.8,
#   'Lng': 81.48,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 75.2,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 1.12,
#   'Country': 'LK'},
#  {'City': 'Farmington',
#   'Lat': 36.73,
#   'Lng': -108.22,
#   'Current Description': 'clear sky',
#   'Max Temp': 33.01,
#   'Humidity': 50,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US'},
#  {'City': 'Kaohsiung',
#   'Lat': 22.62,
#   'Lng': 120.31,
#   'Current Description': 'few clouds',
#   'Max Temp': 73.4,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'TW'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.41,
#   'Current Description': 'light rain',
#   'Max Temp': 33.8,
#   'Humidity': 96,
#   'Cloudiness': 90,
#   'Wind Speed': 10.29,
#   'Country': 'US'},
#  {'City': 'Pevek',
#   'Lat': 69.7,
#   'Lng': 170.31,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -15.57,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 7.05,
#   'Country': 'RU'},
#  {'City': 'Buraydah',
#   'Lat': 26.33,
#   'Lng': 43.98,
#   'Current Description': 'mist',
#   'Max Temp': 53.6,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Country': 'SA'},
#  {'City': 'Olinda',
#   'Lat': -8.01,
#   'Lng': -34.86,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 9.17,
#   'Country': 'BR'},
#  {'City': 'Labuhan',
#   'Lat': -6.88,
#   'Lng': 112.21,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 83.34,
#   'Humidity': 76,
#   'Cloudiness': 98,
#   'Wind Speed': 6.22,
#   'Country': 'ID'},
#  {'City': 'Kolyvan',
#   'Lat': 55.31,
#   'Lng': 82.74,
#   'Current Description': 'clear sky',
#   'Max Temp': -23.8,
#   'Humidity': 74,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'RU'},
#  {'City': 'Touros',
#   'Lat': -5.2,
#   'Lng': -35.46,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'BR'},
#  {'City': 'Airai',
#   'Lat': -8.93,
#   'Lng': 125.41,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 71.49,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 3.69,
#   'Country': 'TL'},
#  {'City': 'Zhanaozen',
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Current Description': 'clear sky',
#   'Max Temp': 20.59,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 11.16,
#   'Country': 'KZ'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.08,
#   'Current Description': 'light rain',
#   'Max Temp': 83.05,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 17.07,
#   'Country': 'MV'},
#  {'City': 'Carnarvon',
#   'Lat': -24.87,
#   'Lng': 113.63,
#   'Current Description': 'clear sky',
#   'Max Temp': 86,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Country': 'AU'},
#  {'City': 'Olafsvik',
#   'Lat': 64.89,
#   'Lng': -23.71,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 38.28,
#   'Humidity': 75,
#   'Cloudiness': 100,
#   'Wind Speed': 18.88,
#   'Country': 'IS'},
#  {'City': 'San Patricio',
#   'Lat': 28.02,
#   'Lng': -97.52,
#   'Current Description': 'clear sky',
#   'Max Temp': 62.6,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US'},
#  {'City': 'Kamyshla',
#   'Lat': 54.12,
#   'Lng': 52.14,
#   'Current Description': 'snow',
#   'Max Temp': 17.51,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 7.92,
#   'Country': 'RU'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.74,
#   'Lng': -90.35,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 72,
#   'Humidity': 91,
#   'Cloudiness': 47,
#   'Wind Speed': 8.43,
#   'Country': 'EC'},
#  {'City': 'Sitka',
#   'Lat': 57.05,
#   'Lng': -135.33,
#   'Current Description': 'moderate rain',
#   'Max Temp': 41,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'US'},
#  {'City': 'Nemuro',
#   'Lat': 43.32,
#   'Lng': 145.57,
#   'Current Description': 'few clouds',
#   'Max Temp': 23,
#   'Humidity': 49,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'JP'},
#  {'City': 'Tura',
#   'Lat': 25.52,
#   'Lng': 90.22,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 70.41,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind Speed': 1.19,
#   'Country': 'IN'},
#  {'City': 'Bujaru',
#   'Lat': -1.51,
#   'Lng': -48.04,
#   'Current Description': 'moderate rain',
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 4.7,
#   'Country': 'BR'},
#  {'City': 'Cape Town',
#   'Lat': -33.93,
#   'Lng': 18.42,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 69.01,
#   'Humidity': 93,
#   'Cloudiness': 40,
#   'Wind Speed': 17.22,
#   'Country': 'ZA'},
#  {'City': 'Rio Grande',
#   'Lat': -32.03,
#   'Lng': -52.1,
#   'Current Description': 'few clouds',
#   'Max Temp': 73.99,
#   'Humidity': 83,
#   'Cloudiness': 11,
#   'Wind Speed': 17.09,
#   'Country': 'BR'},
#  {'City': 'Belize',
#   'Lat': 17.25,
#   'Lng': -88.75,
#   'Current Description': 'clear sky',
#   'Max Temp': 73.99,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 1.61,
#   'Country': 'BZ'},
#  {'City': 'Kapaa',
#   'Lat': 22.08,
#   'Lng': -159.32,
#   'Current Description': 'clear sky',
#   'Max Temp': 78.8,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Country': 'US'},
#  {'City': 'Diapaga',
#   'Lat': 12.07,
#   'Lng': 1.79,
#   'Current Description': 'clear sky',
#   'Max Temp': 75.11,
#   'Humidity': 20,
#   'Cloudiness': 1,
#   'Wind Speed': 5.75,
#   'Country': 'BF'},
#  {'City': 'Zyryanka',
#   'Lat': 65.75,
#   'Lng': 150.85,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -21.42,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 0.31,
#   'Country': 'RU'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.89,
#   'Lng': -109.91,
#   'Current Description': 'clear sky',
#   'Max Temp': 66.2,
#   'Humidity': 45,
#   'Cloudiness': 5,
#   'Wind Speed': 2.24,
#   'Country': 'MX'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.98,
#   'Lng': -114.06,
#   'Current Description': 'broken clouds',
#   'Max Temp': 59.68,
#   'Humidity': 77,
#   'Cloudiness': 56,
#   'Wind Speed': 9.51,
#   'Country': 'MX'},
#  {'City': 'Fortuna',
#   'Lat': 40.6,
#   'Lng': -124.16,
#   'Current Description': 'few clouds',
#   'Max Temp': 46,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 3.38,
#   'Country': 'US'},
#  {'City': 'Castro',
#   'Lat': -24.79,
#   'Lng': -50.01,
#   'Current Description': 'light rain',
#   'Max Temp': 60.82,
#   'Humidity': 96,
#   'Cloudiness': 64,
#   'Wind Speed': 4.97,
#   'Country': 'BR'},
#  {'City': 'Chokurdakh',
#   'Lat': 70.63,
#   'Lng': 147.92,
#   'Current Description': 'scattered clouds',
#   'Max Temp': -26.61,
#   'Humidity': 85,
#   'Cloudiness': 37,
#   'Wind Speed': 10.87,
#   'Country': 'RU'},
#  {'City': 'Torbay',
#   'Lat': 47.67,
#   'Lng': -52.73,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 32,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 17.22,
#   'Country': 'CA'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.36,
#   'Lng': 55.77,
#   'Current Description': 'light rain',
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 14.99,
#   'Country': 'RE'},
#  {'City': 'Pyshchug',
#   'Lat': 58.89,
#   'Lng': 45.71,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 17.73,
#   'Humidity': 98,
#   'Cloudiness': 94,
#   'Wind Speed': 4.68,
#   'Country': 'RU'},
#  {'City': 'Mar Del Plata',
#   'Lat': -38,
#   'Lng': -57.56,
#   'Current Description': 'mist',
#   'Max Temp': 66.99,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 13.87,
#   'Country': 'AR'},
#  {'City': 'Yenagoa',
#   'Lat': 4.92,
#   'Lng': 6.26,
#   'Current Description': 'clear sky',
#   'Max Temp': 76.15,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind Speed': 2.84,
#   'Country': 'NG'},
#  {'City': 'Pesochnoye',
#   'Lat': 58.01,
#   'Lng': 39.18,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 22.75,
#   'Humidity': 98,
#   'Cloudiness': 97,
#   'Wind Speed': 3.91,
#   'Country': 'RU'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.97,
#   'Lng': -42.03,
#   'Current Description': 'clear sky',
#   'Max Temp': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'BR'},
#  {'City': 'Palauig',
#   'Lat': 15.44,
#   'Lng': 119.9,
#   'Current Description': 'broken clouds',
#   'Max Temp': 84.85,
#   'Humidity': 62,
#   'Cloudiness': 55,
#   'Wind Speed': 3.38,
#   'Country': 'PH'},
#  {'City': 'Revda',
#   'Lat': 56.8,
#   'Lng': 59.93,
#   'Current Description': 'light snow',
#   'Max Temp': -0.4,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 8.95,
#   'Country': 'RU'},
#  {'City': 'Saskylakh',
#   'Lat': 71.92,
#   'Lng': 114.08,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 1.11,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 13.82,
#   'Country': 'RU'},
#  {'City': 'Andijon',
#   'Lat': 40.78,
#   'Lng': 72.34,
#   'Current Description': 'fog',
#   'Max Temp': 15.8,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 2.44,
#   'Country': 'UZ'},
#  {'City': 'San Carlos De Bariloche',
#   'Lat': -41.15,
#   'Lng': -71.31,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 62.6,
#   'Humidity': 21,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Country': 'AR'},
#  {'City': 'Nago',
#   'Lat': 26.59,
#   'Lng': 127.98,
#   'Current Description': 'mist',
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Cloudiness': 75,
#   'Wind Speed': 17.22,
#   'Country': 'JP'},
#  {'City': 'Byron Bay',
#   'Lat': -28.65,
#   'Lng': 153.62,
#   'Current Description': 'few clouds',
#   'Max Temp': 90,
#   'Humidity': 66,
#   'Cloudiness': 12,
#   'Wind Speed': 17.22,
#   'Country': 'AU'},
#  {'City': 'Huilong',
#   'Lat': 31.81,
#   'Lng': 121.66,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 50,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'CN'},
#  {'City': 'San Cristobal',
#   'Lat': 7.77,
#   'Lng': -72.22,
#   'Current Description': 'broken clouds',
#   'Max Temp': 62.64,
#   'Humidity': 91,
#   'Cloudiness': 60,
#   'Wind Speed': 1.97,
#   'Country': 'VE'},
#  {'City': 'Ilulissat',
#   'Lat': 69.22,
#   'Lng': -51.1,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 12,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.74,
#   'Country': 'GL'},
#  {'City': 'Fare',
#   'Lat': -16.7,
#   'Lng': -151.02,
#   'Current Description': 'light rain',
#   'Max Temp': 81.68,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 16.62,
#   'Country': 'PF'},
#  {'City': 'Thunder Bay',
#   'Lat': 48.4,
#   'Lng': -89.32,
#   'Current Description': 'broken clouds',
#   'Max Temp': 32,
#   'Humidity': 92,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'CA'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Current Description': 'light rain',
#   'Max Temp': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'TO'},
#  {'City': 'Sabha',
#   'Lat': 27.04,
#   'Lng': 14.43,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 50.68,
#   'Humidity': 50,
#   'Cloudiness': 88,
#   'Wind Speed': 10.25,
#   'Country': 'LY'},
#  {'City': 'Rundu',
#   'Lat': -17.93,
#   'Lng': 19.77,
#   'Current Description': 'moderate rain',
#   'Max Temp': 66.24,
#   'Humidity': 94,
#   'Cloudiness': 97,
#   'Wind Speed': 4,
#   'Country': 'NA'},
#  {'City': 'Johnstown',
#   'Lat': 40.33,
#   'Lng': -78.92,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 32,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 0.81,
#   'Country': 'US'},
#  {'City': 'Fomboni',
#   'Lat': -12.28,
#   'Lng': 43.74,
#   'Current Description': 'clear sky',
#   'Max Temp': 83.44,
#   'Humidity': 70,
#   'Cloudiness': 0,
#   'Wind Speed': 9.26,
#   'Country': 'KM'},
#  {'City': 'Virginia Beach',
#   'Lat': 36.85,
#   'Lng': -75.98,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 45,
#   'Humidity': 75,
#   'Cloudiness': 90,
#   'Wind Speed': 3.36,
#   'Country': 'US'},
#  {'City': 'Presidencia Roque Saenz Pena',
#   'Lat': -26.79,
#   'Lng': -60.44,
#   'Current Description': 'few clouds',
#   'Max Temp': 75,
#   'Humidity': 67,
#   'Cloudiness': 15,
#   'Wind Speed': 3.83,
#   'Country': 'AR'},
#  {'City': 'Westport',
#   'Lat': 41.14,
#   'Lng': -73.36,
#   'Current Description': 'clear sky',
#   'Max Temp': 36,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 5.82,
#   'Country': 'US'},
#  {'City': 'Ramat Yishay',
#   'Lat': 32.7,
#   'Lng': 35.18,
#   'Current Description': 'few clouds',
#   'Max Temp': 64,
#   'Humidity': 60,
#   'Cloudiness': 18,
#   'Wind Speed': 8.99,
#   'Country': 'IL'},
#  {'City': 'Bandarbeyla',
#   'Lat': 9.49,
#   'Lng': 50.81,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 72.09,
#   'Humidity': 70,
#   'Cloudiness': 30,
#   'Wind Speed': 15.93,
#   'Country': 'SO'},
#  {'City': 'Butaritari',
#   'Lat': 3.07,
#   'Lng': 172.79,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 82.27,
#   'Humidity': 77,
#   'Cloudiness': 100,
#   'Wind Speed': 20.11,
#   'Country': 'KI'},
#  {'City': 'Yerbogachen',
#   'Lat': 61.28,
#   'Lng': 108.01,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -25.8,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 9.37,
#   'Country': 'RU'},
#  {'City': 'Hobart',
#   'Lat': -42.88,
#   'Lng': 147.33,
#   'Current Description': 'broken clouds',
#   'Max Temp': 71.01,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'AU'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Current Description': 'broken clouds',
#   'Max Temp': -30.33,
#   'Humidity': 84,
#   'Cloudiness': 84,
#   'Wind Speed': 5.91,
#   'Country': 'RU'},
#  {'City': 'Ukiah',
#   'Lat': 39.15,
#   'Lng': -123.21,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 48.2,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 2.15,
#   'Country': 'US'},
#  {'City': 'Bethel',
#   'Lat': 41.37,
#   'Lng': -73.41,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 33.8,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 3.18,
#   'Country': 'US'},
#  {'City': 'Poum',
#   'Lat': -20.23,
#   'Lng': 164.02,
#   'Current Description': 'broken clouds',
#   'Max Temp': 82.11,
#   'Humidity': 82,
#   'Cloudiness': 52,
#   'Wind Speed': 10.51,
#   'Country': 'NC'},
#  {'City': 'Chuy',
#   'Lat': -33.7,
#   'Lng': -53.46,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 69.87,
#   'Humidity': 87,
#   'Cloudiness': 37,
#   'Wind Speed': 11.32,
#   'Country': 'UY'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.68,
#   'Current Description': 'broken clouds',
#   'Max Temp': -28.91,
#   'Humidity': 84,
#   'Cloudiness': 69,
#   'Wind Speed': 6.2,
#   'Country': 'RU'},
#  {'City': 'Huamachuco',
#   'Lat': -7.8,
#   'Lng': -78.07,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 46.24,
#   'Humidity': 91,
#   'Cloudiness': 96,
#   'Wind Speed': 4.99,
#   'Country': 'PE'},
#  {'City': 'Hilo',
#   'Lat': 19.73,
#   'Lng': -155.09,
#   'Current Description': 'broken clouds',
#   'Max Temp': 78.8,
#   'Humidity': 65,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'US'},
#  {'City': 'Upernavik',
#   'Lat': 72.79,
#   'Lng': -56.15,
#   'Current Description': 'light snow',
#   'Max Temp': 20.05,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 44.11,
#   'Country': 'GL'},
#  {'City': 'Sarandi',
#   'Lat': -23.44,
#   'Lng': -51.87,
#   'Current Description': 'broken clouds',
#   'Max Temp': 69.8,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.7,
#   'Country': 'BR'},
#  {'City': 'Sur',
#   'Lat': 22.57,
#   'Lng': 59.53,
#   'Current Description': 'clear sky',
#   'Max Temp': 66.6,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 12.19,
#   'Country': 'OM'},
#  {'City': 'Harrisburg',
#   'Lat': 40.27,
#   'Lng': -76.88,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 37.99,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 3.24,
#   'Country': 'US'},
#  {'City': 'Kaitangata',
#   'Lat': -46.28,
#   'Lng': 169.85,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'NZ'},
#  {'City': 'Dimovo',
#   'Lat': 43.74,
#   'Lng': 22.73,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 45,
#   'Humidity': 9,
#   'Cloudiness': 100,
#   'Wind Speed': 11.97,
#   'Country': 'BG'},
#  {'City': 'Korla',
#   'Lat': 41.76,
#   'Lng': 86.15,
#   'Current Description': 'clear sky',
#   'Max Temp': 14.94,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 4.23,
#   'Country': 'CN'},
#  {'City': 'Paltinis',
#   'Lat': 48.22,
#   'Lng': 26.65,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 39.99,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 8.99,
#   'Country': 'RO'},
#  {'City': 'Sadon',
#   'Lat': 42.85,
#   'Lng': 44,
#   'Current Description': 'clear sky',
#   'Max Temp': 26.6,
#   'Humidity': 100,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'RU'},
#  {'City': 'Longkou',
#   'Lat': 37.65,
#   'Lng': 120.33,
#   'Current Description': 'clear sky',
#   'Max Temp': 24.78,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 22.19,
#   'Country': 'CN'},
#  {'City': 'Mendi',
#   'Lat': -6.18,
#   'Lng': 143.65,
#   'Current Description': 'moderate rain',
#   'Max Temp': 68.74,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind Speed': 4.21,
#   'Country': 'PG'},
#  {'City': 'Culaman',
#   'Lat': 5.96,
#   'Lng': 125.66,
#   'Current Description': 'light rain',
#   'Max Temp': 84.2,
#   'Humidity': 66,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'PH'},
#  {'City': 'Galiakot',
#   'Lat': 23.52,
#   'Lng': 74,
#   'Current Description': 'light rain',
#   'Max Temp': 66.88,
#   'Humidity': 78,
#   'Cloudiness': 8,
#   'Wind Speed': 3.6,
#   'Country': 'IN'},
#  {'City': 'Rosita',
#   'Lat': 13.93,
#   'Lng': -84.4,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 67.71,
#   'Humidity': 96,
#   'Cloudiness': 28,
#   'Wind Speed': 2.59,
#   'Country': 'NI'},
#  {'City': 'Waipawa',
#   'Lat': -41.41,
#   'Lng': 175.52,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 70,
#   'Humidity': 68,
#   'Cloudiness': 33,
#   'Wind Speed': 23.04,
#   'Country': 'NZ'},
#  {'City': 'Sao Joao Da Barra',
#   'Lat': -21.64,
#   'Lng': -41.05,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 75.54,
#   'Humidity': 90,
#   'Cloudiness': 33,
#   'Wind Speed': 16.71,
#   'Country': 'BR'},
#  {'City': 'Aitape',
#   'Lat': -3.14,
#   'Lng': 142.35,
#   'Current Description': 'moderate rain',
#   'Max Temp': 84.42,
#   'Humidity': 74,
#   'Cloudiness': 93,
#   'Wind Speed': 5.53,
#   'Country': 'PG'},
#  {'City': 'Hasaki',
#   'Lat': 35.73,
#   'Lng': 140.83,
#   'Current Description': 'broken clouds',
#   'Max Temp': 50,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'JP'},
#  {'City': 'Calbuco',
#   'Lat': -41.77,
#   'Lng': -73.13,
#   'Current Description': 'clear sky',
#   'Max Temp': 53.6,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 11.41,
#   'Country': 'CL'},
#  {'City': 'Saldanha',
#   'Lat': -33.01,
#   'Lng': 17.94,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 62.6,
#   'Humidity': 88,
#   'Cloudiness': 44,
#   'Wind Speed': 6.93,
#   'Country': 'ZA'},
#  {'City': 'Santa Rosa',
#   'Lat': 14.31,
#   'Lng': 121.11,
#   'Current Description': 'broken clouds',
#   'Max Temp': 87.01,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'PH'},
#  {'City': 'East London',
#   'Lat': -33.02,
#   'Lng': 27.91,
#   'Current Description': 'clear sky',
#   'Max Temp': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'ZA'},
#  {'City': 'Raglan',
#   'Lat': -37.8,
#   'Lng': 174.88,
#   'Current Description': 'few clouds',
#   'Max Temp': 84,
#   'Humidity': 58,
#   'Cloudiness': 14,
#   'Wind Speed': 10,
#   'Country': 'NZ'},
#  {'City': 'Bairiki',
#   'Lat': 1.33,
#   'Lng': 172.98,
#   'Current Description': 'broken clouds',
#   'Max Temp': 84.2,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'KI'},
#  {'City': 'San Pedro',
#   'Lat': 14.35,
#   'Lng': 121.02,
#   'Current Description': 'broken clouds',
#   'Max Temp': 88,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'PH'},
#  {'City': 'Manacapuru',
#   'Lat': -3.3,
#   'Lng': -60.62,
#   'Current Description': 'clear sky',
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind Speed': 2.66,
#   'Country': 'BR'},
#  {'City': 'Lodja',
#   'Lat': -3.48,
#   'Lng': 23.43,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 67.87,
#   'Humidity': 96,
#   'Cloudiness': 99,
#   'Wind Speed': 1.36,
#   'Country': 'CD'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.52,
#   'Lng': -28.7,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 61.84,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 28.79,
#   'Country': 'PT'},
#  {'City': 'Nyandoma',
#   'Lat': 61.67,
#   'Lng': 40.2,
#   'Current Description': 'broken clouds',
#   'Max Temp': 11.82,
#   'Humidity': 97,
#   'Cloudiness': 69,
#   'Wind Speed': 3.83,
#   'Country': 'RU'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8,
#   'Lng': 102.27,
#   'Current Description': 'moderate rain',
#   'Max Temp': 84.87,
#   'Humidity': 65,
#   'Cloudiness': 68,
#   'Wind Speed': 6.26,
#   'Country': 'ID'},
#  {'City': 'Clyde River',
#   'Lat': 70.47,
#   'Lng': -68.59,
#   'Current Description': 'clear sky',
#   'Max Temp': -20.2,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 4.7,
#   'Country': 'CA'},
#  {'City': 'Adrar',
#   'Lat': 20.5,
#   'Lng': -10.07,
#   'Current Description': 'broken clouds',
#   'Max Temp': 64.06,
#   'Humidity': 38,
#   'Cloudiness': 71,
#   'Wind Speed': 6.8,
#   'Country': 'MR'},
#  {'City': 'Palaikastron',
#   'Lat': 35.2,
#   'Lng': 26.25,
#   'Current Description': 'few clouds',
#   'Max Temp': 57.99,
#   'Humidity': 76,
#   'Cloudiness': 15,
#   'Wind Speed': 10.04,
#   'Country': 'GR'},
#  {'City': 'Isabela',
#   'Lat': 6.71,
#   'Lng': 121.97,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'PH'},
#  {'City': 'Angoche',
#   'Lat': -16.23,
#   'Lng': 39.91,
#   'Current Description': 'clear sky',
#   'Max Temp': 77.04,
#   'Humidity': 85,
#   'Cloudiness': 4,
#   'Wind Speed': 3,
#   'Country': 'MZ'},
#  {'City': 'Mahebourg',
#   'Lat': -20.41,
#   'Lng': 57.7,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'MU'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.34,
#   'Lng': 57.76,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 78.01,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'MU'},
#  {'City': 'Weymouth',
#   'Lat': 42.22,
#   'Lng': -70.94,
#   'Current Description': 'broken clouds',
#   'Max Temp': 35.01,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'US'},
#  {'City': 'Alofi',
#   'Lat': -19.06,
#   'Lng': -169.92,
#   'Current Description': 'moderate rain',
#   'Max Temp': 81.72,
#   'Humidity': 76,
#   'Cloudiness': 91,
#   'Wind Speed': 3.91,
#   'Country': 'NU'},
#  {'City': 'Kavieng',
#   'Lat': -2.57,
#   'Lng': 150.8,
#   'Current Description': 'light rain',
#   'Max Temp': 86,
#   'Humidity': 69,
#   'Cloudiness': 96,
#   'Wind Speed': 11.92,
#   'Country': 'PG'},
#  {'City': 'Tiksi',
#   'Lat': 71.69,
#   'Lng': 128.87,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -13.25,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind Speed': 10.8,
#   'Country': 'RU'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.15,
#   'Lng': -65.71,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -21.59,
#   'Humidity': 81,
#   'Cloudiness': 93,
#   'Wind Speed': 0.96,
#   'Country': 'CA'},
#  {'City': 'Karratha',
#   'Lat': -20.74,
#   'Lng': 116.85,
#   'Current Description': 'few clouds',
#   'Max Temp': 94.71,
#   'Humidity': 34,
#   'Cloudiness': 22,
#   'Wind Speed': 12.26,
#   'Country': 'AU'},
#  {'City': 'Wilmington',
#   'Lat': 34.23,
#   'Lng': -77.94,
#   'Current Description': 'clear sky',
#   'Max Temp': 42.8,
#   'Humidity': 87,
#   'Cloudiness': 1,
#   'Wind Speed': 1.12,
#   'Country': 'US'},
#  {'City': 'Guanica',
#   'Lat': 17.97,
#   'Lng': -66.91,
#   'Current Description': 'clear sky',
#   'Max Temp': 73.99,
#   'Humidity': 77,
#   'Cloudiness': 2,
#   'Wind Speed': 5.75,
#   'Country': 'PR'},
#  {'City': 'Goba',
#   'Lat': 7.02,
#   'Lng': 39.98,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 45.75,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 3.65,
#   'Country': 'ET'},
#  {'City': 'Portland',
#   'Lat': 45.52,
#   'Lng': -122.68,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 46,
#   'Humidity': 89,
#   'Cloudiness': 88,
#   'Wind Speed': 1.99,
#   'Country': 'US'},
#  {'City': 'Talnakh',
#   'Lat': 69.49,
#   'Lng': 88.4,
#   'Current Description': 'light snow',
#   'Max Temp': -14.8,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 15.66,
#   'Country': 'RU'},
#  {'City': 'Lloydminster',
#   'Lat': 53.28,
#   'Lng': -110,
#   'Current Description': 'broken clouds',
#   'Max Temp': 21.2,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 11.41,
#   'Country': 'CA'},
#  {'City': 'Vryburg',
#   'Lat': -26.96,
#   'Lng': 24.73,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 70.54,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 8.5,
#   'Country': 'ZA'},
#  {'City': 'Toropets',
#   'Lat': 56.5,
#   'Lng': 31.64,
#   'Current Description': 'light snow',
#   'Max Temp': 28.49,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind Speed': 4.05,
#   'Country': 'RU'},
#  {'City': 'Jining',
#   'Lat': 35.41,
#   'Lng': 116.58,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 32.68,
#   'Humidity': 76,
#   'Cloudiness': 99,
#   'Wind Speed': 8.03,
#   'Country': 'CN'},
#  {'City': 'Vao',
#   'Lat': -22.67,
#   'Lng': 167.48,
#   'Current Description': 'broken clouds',
#   'Max Temp': 79.45,
#   'Humidity': 84,
#   'Cloudiness': 76,
#   'Wind Speed': 24.23,
#   'Country': 'NC'},
#  {'City': 'Rivne',
#   'Lat': 50.62,
#   'Lng': 26.23,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 41,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 14.81,
#   'Country': 'UA'},
#  {'City': 'Weligama',
#   'Lat': 5.97,
#   'Lng': 80.42,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 79.77,
#   'Humidity': 78,
#   'Cloudiness': 28,
#   'Wind Speed': 4.85,
#   'Country': 'LK'},
#  {'City': 'Sisimiut',
#   'Lat': 66.94,
#   'Lng': -53.67,
#   'Current Description': 'light snow',
#   'Max Temp': 13.28,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.78,
#   'Country': 'GL'},
#  {'City': 'Ossora',
#   'Lat': 59.24,
#   'Lng': 163.07,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -3.42,
#   'Humidity': 89,
#   'Cloudiness': 98,
#   'Wind Speed': 7.56,
#   'Country': 'RU'},
#  {'City': 'Tunceli',
#   'Lat': 39.11,
#   'Lng': 39.55,
#   'Current Description': 'fog',
#   'Max Temp': 26.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'TR'},
#  {'City': 'Tuatapere',
#   'Lat': -46.13,
#   'Lng': 167.68,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 55.74,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 0.94,
#   'Country': 'NZ'},
#  {'City': 'Coahuayana',
#   'Lat': 18.73,
#   'Lng': -103.68,
#   'Current Description': 'clear sky',
#   'Max Temp': 73.4,
#   'Humidity': 73,
#   'Cloudiness': 5,
#   'Wind Speed': 2.53,
#   'Country': 'MX'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.05,
#   'Lng': 158.65,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 21.2,
#   'Humidity': 67,
#   'Cloudiness': 40,
#   'Wind Speed': 4.47,
#   'Country': 'RU'},
#  {'City': 'Rio Gallegos',
#   'Lat': -51.62,
#   'Lng': -69.22,
#   'Current Description': 'clear sky',
#   'Max Temp': 57.2,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind Speed': 5.82,
#   'Country': 'AR'},
#  {'City': 'Rawson',
#   'Lat': -43.3,
#   'Lng': -65.1,
#   'Current Description': 'clear sky',
#   'Max Temp': 59.31,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind Speed': 12.03,
#   'Country': 'AR'},
#  {'City': 'Itarema',
#   'Lat': -2.92,
#   'Lng': -39.92,
#   'Current Description': 'clear sky',
#   'Max Temp': 78.64,
#   'Humidity': 83,
#   'Cloudiness': 9,
#   'Wind Speed': 12.12,
#   'Country': 'BR'},
#  {'City': 'Kamachumu',
#   'Lat': -1.62,
#   'Lng': 31.62,
#   'Current Description': 'broken clouds',
#   'Max Temp': 66.2,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 2.28,
#   'Country': 'TZ'},
#  {'City': 'Sumenep',
#   'Lat': -7.02,
#   'Lng': 113.87,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 85.86,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 6.71,
#   'Country': 'ID'},
#  {'City': 'Nikolskoye',
#   'Lat': 59.7,
#   'Lng': 30.79,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 28,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'RU'},
#  {'City': 'Burnie',
#   'Lat': -41.07,
#   'Lng': 145.92,
#   'Current Description': 'broken clouds',
#   'Max Temp': 70,
#   'Humidity': 54,
#   'Cloudiness': 70,
#   'Wind Speed': 13,
#   'Country': 'AU'},
#  {'City': 'Melilla',
#   'Lat': 35.29,
#   'Lng': -2.94,
#   'Current Description': 'clear sky',
#   'Max Temp': 46.4,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'ES'},
#  {'City': 'Grindavik',
#   'Lat': 63.84,
#   'Lng': -22.43,
#   'Current Description': 'broken clouds',
#   'Max Temp': 35.6,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 5.82,
#   'Country': 'IS'},
#  {'City': 'Fairbanks',
#   'Lat': 64.84,
#   'Lng': -147.72,
#   'Current Description': 'few clouds',
#   'Max Temp': -9.99,
#   'Humidity': 75,
#   'Cloudiness': 20,
#   'Wind Speed': 1.12,
#   'Country': 'US'},
#  {'City': 'Georgiyevka',
#   'Lat': 43.04,
#   'Lng': 74.71,
#   'Current Description': 'fog',
#   'Max Temp': -5.8,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Country': 'KZ'},
#  {'City': 'Japura',
#   'Lat': -0.32,
#   'Lng': 102.35,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 84.9,
#   'Humidity': 64,
#   'Cloudiness': 44,
#   'Wind Speed': 4.74,
#   'Country': 'ID'},
#  {'City': 'Durusu',
#   'Lat': 41.31,
#   'Lng': 28.68,
#   'Current Description': 'broken clouds',
#   'Max Temp': 53.6,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'TR'},
#  {'City': 'Birin',
#   'Lat': 26.89,
#   'Lng': 88.07,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 57.54,
#   'Humidity': 59,
#   'Cloudiness': 100,
#   'Wind Speed': 2.13,
#   'Country': 'NP'},
#  {'City': 'Ternovka',
#   'Lat': 51.68,
#   'Lng': 41.64,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 26.26,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 9.4,
#   'Country': 'RU'},
#  {'City': 'Sabang',
#   'Lat': 5.89,
#   'Lng': 95.32,
#   'Current Description': 'moderate rain',
#   'Max Temp': 78.57,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 12.33,
#   'Country': 'ID'},
#  {'City': 'Mildura',
#   'Lat': -34.2,
#   'Lng': 142.15,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 73.99,
#   'Humidity': 43,
#   'Cloudiness': 40,
#   'Wind Speed': 12.75,
#   'Country': 'AU'},
#  {'City': 'Erzin',
#   'Lat': 36.96,
#   'Lng': 36.2,
#   'Current Description': 'few clouds',
#   'Max Temp': 51.8,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'TR'},
#  {'City': 'Atar',
#   'Lat': 20.52,
#   'Lng': -13.05,
#   'Current Description': 'broken clouds',
#   'Max Temp': 68.02,
#   'Humidity': 38,
#   'Cloudiness': 54,
#   'Wind Speed': 4.83,
#   'Country': 'MR'},
#  {'City': 'Phan Thiet',
#   'Lat': 10.93,
#   'Lng': 108.1,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 81.55,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind Speed': 10.69,
#   'Country': 'VN'},
#  {'City': 'Saint George',
#   'Lat': 37.1,
#   'Lng': -113.58,
#   'Current Description': 'clear sky',
#   'Max Temp': 48,
#   'Humidity': 36,
#   'Cloudiness': 1,
#   'Wind Speed': 8.05,
#   'Country': 'US'},
#  {'City': 'San Felipe',
#   'Lat': 10.34,
#   'Lng': -68.74,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 67.6,
#   'Humidity': 91,
#   'Cloudiness': 40,
#   'Wind Speed': 1.12,
#   'Country': 'VE'},
#  {'City': 'Onega',
#   'Lat': 63.91,
#   'Lng': 38.14,
#   'Current Description': 'broken clouds',
#   'Max Temp': 7.48,
#   'Humidity': 95,
#   'Cloudiness': 72,
#   'Wind Speed': 3.49,
#   'Country': 'RU'},
#  {'City': 'Vanimo',
#   'Lat': -2.67,
#   'Lng': 141.3,
#   'Current Description': 'light rain',
#   'Max Temp': 86.25,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 5.79,
#   'Country': 'PG'},
#  {'City': 'Salalah',
#   'Lat': 17.02,
#   'Lng': 54.09,
#   'Current Description': 'clear sky',
#   'Max Temp': 68,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind Speed': 10.29,
#   'Country': 'OM'},
#  {'City': 'Deputatskiy',
#   'Lat': 69.3,
#   'Lng': 139.9,
#   'Current Description': 'scattered clouds',
#   'Max Temp': -29.27,
#   'Humidity': 84,
#   'Cloudiness': 34,
#   'Wind Speed': 5.68,
#   'Country': 'RU'},
#  {'City': 'Conde',
#   'Lat': -7.26,
#   'Lng': -34.91,
#   'Current Description': 'broken clouds',
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'BR'},
#  {'City': 'Villazon',
#   'Lat': -22.09,
#   'Lng': -65.59,
#   'Current Description': 'light rain',
#   'Max Temp': 49.62,
#   'Humidity': 71,
#   'Cloudiness': 76,
#   'Wind Speed': 6.89,
#   'Country': 'BO'},
#  {'City': 'Abonnema',
#   'Lat': 4.71,
#   'Lng': 6.79,
#   'Current Description': 'clear sky',
#   'Max Temp': 77.86,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind Speed': 3.76,
#   'Country': 'NG'},
#  {'City': 'Malatya',
#   'Lat': 38.5,
#   'Lng': 38,
#   'Current Description': 'mist',
#   'Max Temp': 30.2,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 1.12,
#   'Country': 'TR'},
#  {'City': 'Bekobod',
#   'Lat': 40.22,
#   'Lng': 69.27,
#   'Current Description': 'mist',
#   'Max Temp': 19.4,
#   'Humidity': 92,
#   'Cloudiness': 90,
#   'Wind Speed': 8.95,
#   'Country': 'UZ'},
#  {'City': 'Kajansi',
#   'Lat': 0.21,
#   'Lng': 32.52,
#   'Current Description': 'few clouds',
#   'Max Temp': 68,
#   'Humidity': 82,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'UG'},
#  {'City': 'Heihe',
#   'Lat': 50.24,
#   'Lng': 127.49,
#   'Current Description': 'clear sky',
#   'Max Temp': -11.2,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 4.47,
#   'Country': 'CN'},
#  {'City': 'Hami',
#   'Lat': 42.8,
#   'Lng': 93.45,
#   'Current Description': 'clear sky',
#   'Max Temp': 9.86,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 6.06,
#   'Country': 'CN'},
#  {'City': 'San Policarpo',
#   'Lat': 12.18,
#   'Lng': 125.51,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 83.93,
#   'Humidity': 67,
#   'Cloudiness': 100,
#   'Wind Speed': 12.5,
#   'Country': 'PH'},
#  {'City': 'Lancaster',
#   'Lat': 40.25,
#   'Lng': -76.25,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 39.2,
#   'Humidity': 90,
#   'Cloudiness': 90,
#   'Wind Speed': 3.27,
#   'Country': 'US'},
#  {'City': 'Sokoni',
#   'Lat': -6.43,
#   'Lng': 39.55,
#   'Current Description': 'light rain',
#   'Max Temp': 80.6,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 14.74,
#   'Country': 'TZ'},
#  {'City': 'Mangrul Pir',
#   'Lat': 20.32,
#   'Lng': 77.35,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 69.66,
#   'Humidity': 50,
#   'Cloudiness': 99,
#   'Wind Speed': 5.99,
#   'Country': 'IN'},
#  {'City': 'Lebu',
#   'Lat': -37.62,
#   'Lng': -73.65,
#   'Current Description': 'clear sky',
#   'Max Temp': 55.87,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind Speed': 20.31,
#   'Country': 'CL'},
#  {'City': 'Baruun-Urt',
#   'Lat': 46.68,
#   'Lng': 113.28,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -18.04,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.46,
#   'Country': 'MN'},
#  {'City': 'Tuy Hoa',
#   'Lat': 13.08,
#   'Lng': 109.3,
#   'Current Description': 'light rain',
#   'Max Temp': 75.65,
#   'Humidity': 89,
#   'Cloudiness': 80,
#   'Wind Speed': 14.9,
#   'Country': 'VN'},
#  {'City': 'Ribeira Brava',
#   'Lat': 32.65,
#   'Lng': -17.07,
#   'Current Description': 'light intensity shower rain',
#   'Max Temp': 62.6,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind Speed': 4.7,
#   'Country': 'PT'},
#  {'City': 'Oliveira Dos Brejinhos',
#   'Lat': -12.32,
#   'Lng': -42.9,
#   'Current Description': 'few clouds',
#   'Max Temp': 70.65,
#   'Humidity': 77,
#   'Cloudiness': 12,
#   'Wind Speed': 2.46,
#   'Country': 'BR'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.81,
#   'Lng': -122.7,
#   'Current Description': 'snow',
#   'Max Temp': -5.8,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind Speed': 5.82,
#   'Country': 'CA'},
#  {'City': 'Ingham',
#   'Lat': 42.6,
#   'Lng': -84.38,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 30.2,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 4.7,
#   'Country': 'US'},
#  {'City': 'Nhulunbuy',
#   'Lat': -12.23,
#   'Lng': 136.77,
#   'Current Description': 'broken clouds',
#   'Max Temp': 89.6,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'AU'},
#  {'City': 'Kloulklubed',
#   'Lat': 7.04,
#   'Lng': 134.26,
#   'Current Description': 'light rain',
#   'Max Temp': 86,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 13.87,
#   'Country': 'PW'},
#  {'City': 'Berlevag',
#   'Lat': 70.86,
#   'Lng': 29.09,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 36.14,
#   'Humidity': 81,
#   'Cloudiness': 88,
#   'Wind Speed': 17.87,
#   'Country': 'NO'},
#  {'City': 'Pimentel',
#   'Lat': -6.84,
#   'Lng': -79.93,
#   'Current Description': 'broken clouds',
#   'Max Temp': 68.94,
#   'Humidity': 84,
#   'Cloudiness': 80,
#   'Wind Speed': 9.19,
#   'Country': 'PE'},
#  {'City': 'Muros',
# ...
#   'Max Temp': 78.8,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'BR'},
#  {'City': 'Puerto Quijarro',
#   'Lat': -17.78,
#   'Lng': -57.77,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 72.63,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.44,
#   'Country': 'BO'},
#  {'City': 'Puksoozero',
#   'Lat': 62.59,
#   'Lng': 40.61,
#   'Current Description': 'broken clouds',
#   'Max Temp': 10.45,
#   'Humidity': 97,
#   'Cloudiness': 75,
#   'Wind Speed': 2.51,
#   'Country': 'RU'},
#  {'City': 'Gewane',
#   'Lat': 10.17,
#   'Lng': 40.65,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 67.03,
#   'Humidity': 60,
#   'Cloudiness': 85,
#   'Wind Speed': 3.91,
#   'Country': 'ET'},
#  {'City': 'Filimonovo',
#   'Lat': 56.2,
#   'Lng': 95.46,
#   'Current Description': 'clear sky',
#   'Max Temp': -25.65,
#   'Humidity': 83,
#   'Cloudiness': 10,
#   'Wind Speed': 10.31,
#   'Country': 'RU'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.43,
#   'Lng': 71.72,
#   'Current Description': 'mist',
#   'Max Temp': 19.4,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 2.24,
#   'Country': 'UZ'},
#  {'City': 'Umm Lajj',
#   'Lat': 25.02,
#   'Lng': 37.27,
#   'Current Description': 'clear sky',
#   'Max Temp': 71.87,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 5.32,
#   'Country': 'SA'},
#  {'City': 'Camana',
#   'Lat': -16.62,
#   'Lng': -72.71,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 71.22,
#   'Humidity': 76,
#   'Cloudiness': 47,
#   'Wind Speed': 3.49,
#   'Country': 'PE'},
#  {'City': 'Manzil Salim',
#   'Lat': 35.86,
#   'Lng': 8.48,
#   'Current Description': 'clear sky',
#   'Max Temp': 37.4,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 2.24,
#   'Country': 'TN'},
#  {'City': 'Zambezi',
#   'Lat': -13.54,
#   'Lng': 23.1,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 63.1,
#   'Humidity': 95,
#   'Cloudiness': 90,
#   'Wind Speed': 5.59,
#   'Country': 'ZM'},
#  {'City': 'Filotion',
#   'Lat': 37.05,
#   'Lng': 25.5,
#   'Current Description': 'clear sky',
#   'Max Temp': 59,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'GR'},
#  {'City': 'Kudahuvadhoo',
#   'Lat': 2.67,
#   'Lng': 72.89,
#   'Current Description': 'moderate rain',
#   'Max Temp': 82.11,
#   'Humidity': 74,
#   'Cloudiness': 98,
#   'Wind Speed': 4.85,
#   'Country': 'MV'},
#  {'City': 'Havoysund',
#   'Lat': 71,
#   'Lng': 24.66,
#   'Current Description': 'light rain',
#   'Max Temp': 39.2,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 14.99,
#   'Country': 'NO'},
#  {'City': 'High Level',
#   'Lat': 58.52,
#   'Lng': -117.14,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -5.8,
#   'Humidity': 91,
#   'Cloudiness': 90,
#   'Wind Speed': 2.24,
#   'Country': 'CA'},
#  {'City': 'Cabedelo',
#   'Lat': -6.98,
#   'Lng': -34.83,
#   'Current Description': 'few clouds',
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 6.93,
#   'Country': 'BR'},
#  {'City': 'Port Moresby',
#   'Lat': -9.44,
#   'Lng': 147.18,
#   'Current Description': 'haze',
#   'Max Temp': 91.4,
#   'Humidity': 55,
#   'Cloudiness': 20,
#   'Wind Speed': 11.41,
#   'Country': 'PG'},
#  {'City': 'Hirara',
#   'Lat': 24.8,
#   'Lng': 125.28,
#   'Current Description': 'broken clouds',
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 18.34,
#   'Country': 'JP'},
#  {'City': 'Madimba',
#   'Lat': -10.4,
#   'Lng': 40.33,
#   'Current Description': 'light rain',
#   'Max Temp': 77,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 9.17,
#   'Country': 'TZ'},
#  {'City': 'Ahipara',
#   'Lat': -35.17,
#   'Lng': 173.17,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 73.54,
#   'Humidity': 60,
#   'Cloudiness': 25,
#   'Wind Speed': 2.08,
#   'Country': 'NZ'},
#  {'City': 'Grand Forks',
#   'Lat': 47.94,
#   'Lng': -97.43,
#   'Current Description': 'clear sky',
#   'Max Temp': 30.2,
#   'Humidity': 80,
#   'Cloudiness': 1,
#   'Wind Speed': 9.17,
#   'Country': 'US'},
#  {'City': 'Sola',
#   'Lat': -13.88,
#   'Lng': 167.55,
#   'Current Description': 'broken clouds',
#   'Max Temp': 84.2,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 9.62,
#   'Country': 'VU'},
#  {'City': 'Taonan',
#   'Lat': 45.33,
#   'Lng': 122.78,
#   'Current Description': 'clear sky',
#   'Max Temp': 1.56,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 6.08,
#   'Country': 'CN'},
#  {'City': 'Iqaluit',
#   'Lat': 63.75,
#   'Lng': -68.51,
#   'Current Description': 'few clouds',
#   'Max Temp': -22,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 4.7,
#   'Country': 'CA'},
#  {'City': 'Puerto Del Rosario',
#   'Lat': 28.5,
#   'Lng': -13.86,
#   'Current Description': 'clear sky',
#   'Max Temp': 66.2,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'ES'},
#  {'City': 'Uvat',
#   'Lat': 59.14,
#   'Lng': 68.9,
#   'Current Description': 'broken clouds',
#   'Max Temp': -14.26,
#   'Humidity': 87,
#   'Cloudiness': 78,
#   'Wind Speed': 6.76,
#   'Country': 'RU'},
#  {'City': 'Tucurui',
#   'Lat': -3.77,
#   'Lng': -49.67,
#   'Current Description': 'light rain',
#   'Max Temp': 74.05,
#   'Humidity': 93,
#   'Cloudiness': 85,
#   'Wind Speed': 2.95,
#   'Country': 'BR'},
#  {'City': 'Serenje',
#   'Lat': -13.23,
#   'Lng': 30.24,
#   'Current Description': 'light rain',
#   'Max Temp': 61.09,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 3.13,
#   'Country': 'ZM'},
#  {'City': 'Kysyl-Syr',
#   'Lat': 63.9,
#   'Lng': 122.76,
#   'Current Description': 'scattered clouds',
#   'Max Temp': -39.91,
#   'Humidity': 80,
#   'Cloudiness': 50,
#   'Wind Speed': 4.41,
#   'Country': 'RU'},
#  {'City': 'Passos',
#   'Lat': -20.72,
#   'Lng': -46.61,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 66.43,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind Speed': 3,
#   'Country': 'BR'},
#  {'City': 'Banjar',
#   'Lat': -8.19,
#   'Lng': 114.97,
#   'Current Description': 'light rain',
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 6.93,
#   'Country': 'ID'},
#  {'City': 'Loten',
#   'Lat': 60.82,
#   'Lng': 11.34,
#   'Current Description': 'broken clouds',
#   'Max Temp': 19.99,
#   'Humidity': 91,
#   'Cloudiness': 68,
#   'Wind Speed': 1.66,
#   'Country': 'NO'},
#  {'City': 'Wajima',
#   'Lat': 37.4,
#   'Lng': 136.9,
#   'Current Description': 'light rain',
#   'Max Temp': 35.6,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 9.17,
#   'Country': 'JP'},
#  {'City': 'Shirvan',
#   'Lat': 39.95,
#   'Lng': 48.9,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 43.38,
#   'Humidity': 80,
#   'Cloudiness': 97,
#   'Wind Speed': 3.83,
#   'Country': 'AZ'},
#  {'City': 'Xai-Xai',
#   'Lat': -25.05,
#   'Lng': 33.64,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 72.07,
#   'Humidity': 89,
#   'Cloudiness': 45,
#   'Wind Speed': 4.65,
#   'Country': 'MZ'},
#  {'City': 'Kirkenaer',
#   'Lat': 60.46,
#   'Lng': 12.06,
#   'Current Description': 'clear sky',
#   'Max Temp': 24.8,
#   'Humidity': 92,
#   'Cloudiness': 0,
#   'Wind Speed': 8.05,
#   'Country': 'NO'},
#  {'City': 'Ust-Nera',
#   'Lat': 64.57,
#   'Lng': 143.2,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -17.48,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind Speed': 2.62,
#   'Country': 'RU'},
#  {'City': 'Gwanda',
#   'Lat': -20.93,
#   'Lng': 29,
#   'Current Description': 'clear sky',
#   'Max Temp': 66.96,
#   'Humidity': 86,
#   'Cloudiness': 3,
#   'Wind Speed': 5.03,
#   'Country': 'ZW'},
#  {'City': 'Goderich',
#   'Lat': 43.75,
#   'Lng': -81.72,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 33.8,
#   'Humidity': 74,
#   'Cloudiness': 99,
#   'Wind Speed': 9.17,
#   'Country': 'CA'},
#  {'City': 'Tomatlan',
#   'Lat': 19.93,
#   'Lng': -105.25,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 67.62,
#   'Humidity': 72,
#   'Cloudiness': 32,
#   'Wind Speed': 1.88,
#   'Country': 'MX'},
#  {'City': 'Prince George',
#   'Lat': 53.92,
#   'Lng': -122.75,
#   'Current Description': 'mist',
#   'Max Temp': 30,
#   'Humidity': 100,
#   'Cloudiness': 20,
#   'Wind Speed': 5.82,
#   'Country': 'CA'},
#  {'City': 'Myanaung',
#   'Lat': 18.28,
#   'Lng': 95.32,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 75.9,
#   'Humidity': 59,
#   'Cloudiness': 44,
#   'Wind Speed': 8.99,
#   'Country': 'MM'},
#  {'City': 'Guerrero',
#   'Lat': 17.67,
#   'Lng': -100,
#   'Current Description': 'clear sky',
#   'Max Temp': 64.8,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind Speed': 3.36,
#   'Country': 'MX'},
#  {'City': 'Wellington',
#   'Lat': -41.29,
#   'Lng': 174.78,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 70,
#   'Humidity': 68,
#   'Cloudiness': 33,
#   'Wind Speed': 23.04,
#   'Country': 'NZ'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.78,
#   'Current Description': 'few clouds',
#   'Max Temp': 73.83,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind Speed': 8.75,
#   'Country': 'NZ'},
#  {'City': 'Souillac',
#   'Lat': -20.52,
#   'Lng': 57.52,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 77,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind Speed': 6.93,
#   'Country': 'MU'},
#  {'City': 'Kosa',
#   'Lat': 59.94,
#   'Lng': 55,
#   'Current Description': 'broken clouds',
#   'Max Temp': 9.9,
#   'Humidity': 96,
#   'Cloudiness': 79,
#   'Wind Speed': 5.77,
#   'Country': 'RU'},
#  {'City': 'Hoa Binh',
#   'Lat': 20.81,
#   'Lng': 105.34,
#   'Current Description': 'haze',
#   'Max Temp': 62.6,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 3.36,
#   'Country': 'VN'},
#  {'City': 'Baoning',
#   'Lat': 25.34,
#   'Lng': 110.03,
#   'Current Description': 'broken clouds',
#   'Max Temp': 51.8,
#   'Humidity': 62,
#   'Cloudiness': 75,
#   'Wind Speed': 4.47,
#   'Country': 'CN'},
#  {'City': 'Zima',
#   'Lat': 53.92,
#   'Lng': 102.04,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -20.65,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 10.6,
#   'Country': 'RU'},
#  {'City': 'Luebo',
#   'Lat': -5.35,
#   'Lng': 21.42,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 68.68,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 1.61,
#   'Country': 'CD'},
#  {'City': 'Sao Jose Da Coroa Grande',
#   'Lat': -8.9,
#   'Lng': -35.15,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 76.69,
#   'Humidity': 81,
#   'Cloudiness': 44,
#   'Wind Speed': 9.24,
#   'Country': 'BR'},
#  {'City': 'Yeniseysk',
#   'Lat': 58.45,
#   'Lng': 92.17,
#   'Current Description': 'broken clouds',
#   'Max Temp': -24.81,
#   'Humidity': 85,
#   'Cloudiness': 59,
#   'Wind Speed': 4.38,
#   'Country': 'RU'},
#  {'City': 'Padilla',
#   'Lat': 3.22,
#   'Lng': -76.31,
#   'Current Description': 'light rain',
#   'Max Temp': 69.8,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind Speed': 5.82,
#   'Country': 'CO'},
#  {'City': 'Oxford',
#   'Lat': 51.75,
#   'Lng': -1.26,
#   'Current Description': 'broken clouds',
#   'Max Temp': 35.6,
#   'Humidity': 97,
#   'Cloudiness': 51,
#   'Wind Speed': 10.29,
#   'Country': 'GB'},
#  {'City': 'Rayong',
#   'Lat': 12.83,
#   'Lng': 101.43,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 84.99,
#   'Humidity': 53,
#   'Cloudiness': 25,
#   'Wind Speed': 7.87,
#   'Country': 'TH'},
#  {'City': 'Nantucket',
#   'Lat': 41.28,
#   'Lng': -70.1,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 39.99,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind Speed': 19.46,
#   'Country': 'US'},
#  {'City': 'Povenets',
#   'Lat': 62.85,
#   'Lng': 34.83,
#   'Current Description': 'light snow',
#   'Max Temp': 13.41,
#   'Humidity': 95,
#   'Cloudiness': 69,
#   'Wind Speed': 4.34,
#   'Country': 'RU'},
#  {'City': 'Harmanli',
#   'Lat': 41.93,
#   'Lng': 25.9,
#   'Current Description': 'few clouds',
#   'Max Temp': 51.01,
#   'Humidity': 10,
#   'Cloudiness': 20,
#   'Wind Speed': 7.52,
#   'Country': 'BG'},
#  {'City': 'Guanare',
#   'Lat': 9.04,
#   'Lng': -69.74,
#   'Current Description': 'clear sky',
#   'Max Temp': 69.82,
#   'Humidity': 64,
#   'Cloudiness': 0,
#   'Wind Speed': 2.93,
#   'Country': 'VE'},
#  {'City': 'Murighiol',
#   'Lat': 45.03,
#   'Lng': 29.17,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 46.4,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 11.41,
#   'Country': 'RO'},
#  {'City': 'Khartoum',
#   'Lat': 15.55,
#   'Lng': 32.53,
#   'Current Description': 'clear sky',
#   'Max Temp': 73,
#   'Humidity': 43,
#   'Cloudiness': 0,
#   'Wind Speed': 9.17,
#   'Country': 'SD'},
#  {'City': 'Masterton',
#   'Lat': -40.96,
#   'Lng': 175.66,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 73,
#   'Humidity': 70,
#   'Cloudiness': 31,
#   'Wind Speed': 1.99,
#   'Country': 'NZ'},
#  {'City': 'Bonavista',
#   'Lat': 48.65,
#   'Lng': -53.11,
#   'Current Description': 'broken clouds',
#   'Max Temp': 24.8,
#   'Humidity': 92,
#   'Cloudiness': 62,
#   'Wind Speed': 3.36,
#   'Country': 'CA'},
#  {'City': 'Manavalakurichi',
#   'Lat': 8.13,
#   'Lng': 77.3,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 2.24,
#   'Country': 'IN'},
#  {'City': 'Jinka',
#   'Lat': 5.65,
#   'Lng': 36.65,
#   'Current Description': 'clear sky',
#   'Max Temp': 62.67,
#   'Humidity': 71,
#   'Cloudiness': 9,
#   'Wind Speed': 2.51,
#   'Country': 'ET'},
#  {'City': 'Sungaipenuh',
#   'Lat': -2.08,
#   'Lng': 101.38,
#   'Current Description': 'broken clouds',
#   'Max Temp': 79.36,
#   'Humidity': 59,
#   'Cloudiness': 64,
#   'Wind Speed': 1.1,
#   'Country': 'ID'},
#  {'City': 'Gobabis',
#   'Lat': -22.45,
#   'Lng': 18.97,
#   'Current Description': 'light rain',
#   'Max Temp': 66.2,
#   'Humidity': 93,
#   'Cloudiness': 77,
#   'Wind Speed': 2.93,
#   'Country': 'NA'},
#  {'City': 'Queenstown',
#   'Lat': -31.9,
#   'Lng': 26.88,
#   'Current Description': 'broken clouds',
#   'Max Temp': 63.25,
#   'Humidity': 81,
#   'Cloudiness': 56,
#   'Wind Speed': 3.24,
#   'Country': 'ZA'},
#  {'City': 'Benguela',
#   'Lat': -12.58,
#   'Lng': 13.41,
#   'Current Description': 'broken clouds',
#   'Max Temp': 74.14,
#   'Humidity': 79,
#   'Cloudiness': 72,
#   'Wind Speed': 2.53,
#   'Country': 'AO'},
#  {'City': 'Aklavik',
#   'Lat': 68.22,
#   'Lng': -135.01,
#   'Current Description': 'overcast clouds',
#   'Max Temp': -11.2,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 5.82,
#   'Country': 'CA'},
#  {'City': 'Ponta Delgada',
#   'Lat': 37.73,
#   'Lng': -25.67,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 59,
#   'Humidity': 87,
#   'Cloudiness': 40,
#   'Wind Speed': 16.11,
#   'Country': 'PT'},
#  {'City': 'Abaete',
#   'Lat': -19.16,
#   'Lng': -45.45,
#   'Current Description': 'broken clouds',
#   'Max Temp': 69.55,
#   'Humidity': 88,
#   'Cloudiness': 83,
#   'Wind Speed': 2.24,
#   'Country': 'BR'},
#  {'City': 'Birobidzhan',
#   'Lat': 48.8,
#   'Lng': 132.95,
#   'Current Description': 'clear sky',
#   'Max Temp': -6.38,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 2.57,
#   'Country': 'RU'},
#  {'City': 'Owando',
#   'Lat': -0.48,
#   'Lng': 15.9,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 71.53,
#   'Humidity': 85,
#   'Cloudiness': 96,
#   'Wind Speed': 2.3,
#   'Country': 'CG'},
#  {'City': 'Ippy',
#   'Lat': 6.27,
#   'Lng': 21.22,
#   'Current Description': 'clear sky',
#   'Max Temp': 70.52,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 4.14,
#   'Country': 'CF'},
#  {'City': 'Bontang',
#   'Lat': 0.13,
#   'Lng': 117.5,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 82.11,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 5.35,
#   'Country': 'ID'},
#  {'City': 'San Jose',
#   'Lat': 37.34,
#   'Lng': -121.89,
#   'Current Description': 'scattered clouds',
#   'Max Temp': 54,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind Speed': 0.96,
#   'Country': 'US'},
#  {'City': 'Winslow',
#   'Lat': 35.02,
#   'Lng': -110.7,
#   'Current Description': 'clear sky',
#   'Max Temp': 33.8,
#   'Humidity': 34,
#   'Cloudiness': 1,
#   'Wind Speed': 3.36,
#   'Country': 'US'},
#  {'City': 'Garowe',
#   'Lat': 8.41,
#   'Lng': 48.48,
#   'Current Description': 'broken clouds',
#   'Max Temp': 64.29,
#   'Humidity': 70,
#   'Cloudiness': 83,
#   'Wind Speed': 9.06,
#   'Country': 'SO'},
#  {'City': 'Victor Harbor',
#   'Lat': -35.57,
#   'Lng': 138.62,
#   'Current Description': 'overcast clouds',
#   'Max Temp': 71.01,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'AU'},
#  {'City': 'Yashkino',
#   'Lat': 55.87,
#   'Lng': 85.43,
#   'Current Description': 'clear sky',
#   'Max Temp': -11.2,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 1.03,
#   'Country': 'RU'},
#  {'City': 'Lokosovo',
#   'Lat': 61.13,
#   'Lng': 74.82,
#   'Current Description': 'clear sky',
#   'Max Temp': -22.56,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 5.95,
#   'Country': 'RU'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_sub_df = pd.DataFrame(city_data2)
city_data_sub_df.head(10)
# Out:
#            City    Lat     Lng Current Description  Max Temp  Humidity  \
# 0        Atuona  -9.80 -139.03     overcast clouds     78.33        77
# 1  Longyearbyen  78.22   15.64                snow     28.40        92
# 2     Busselton -33.65  115.33           clear sky     80.01        40
# 3     Raudeberg  61.99    5.14     overcast clouds     30.20        74
# 4    Bredasdorp -34.53   20.04          light rain     69.80        83
# 5        Shingu  33.73  135.98       broken clouds     46.40        49
# 6     Jamestown  42.10  -79.24                mist     33.01       100
# 7       Rikitea -23.12 -134.97          few clouds     76.89        73
# 8      Vanavara  60.34  102.28     overcast clouds    -27.40        83
# 9        Avarua -21.21 -159.78    scattered clouds     84.20        70
#
#    Cloudiness  Wind Speed Country
# 0          91       16.28      PF
# 1          90       47.20      SJ
# 2           0        8.01      AU
# 3          91        9.17      NO
# 4         100        8.05      ZA
# 5          75       11.41      JP
# 6          90        4.70      US
# 7          12       17.11      PF
# 8         100        7.72      RU
# 9          39       14.99      CK

# %%
new_column_order=["City","Country","Lat","Lng","Max Temp","Humidity","Cloudiness","Wind Speed","Current Description"]
city_data_sub_df = city_data_sub_df[new_column_order]
city_data_sub_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0        Atuona      PF  -9.80 -139.03     78.33        77          91
# 1  Longyearbyen      SJ  78.22   15.64     28.40        92          90
# 2     Busselton      AU -33.65  115.33     80.01        40           0
# 3     Raudeberg      NO  61.99    5.14     30.20        74          91
# 4    Bredasdorp      ZA -34.53   20.04     69.80        83         100
# 5        Shingu      JP  33.73  135.98     46.40        49          75
# 6     Jamestown      US  42.10  -79.24     33.01       100          90
# 7       Rikitea      PF -23.12 -134.97     76.89        73          12
# 8      Vanavara      RU  60.34  102.28    -27.40        83         100
# 9        Avarua      CK -21.21 -159.78     84.20        70          39
#
#    Wind Speed Current Description
# 0       16.28     overcast clouds
# 1       47.20                snow
# 2        8.01           clear sky
# 3        9.17     overcast clouds
# 4        8.05          light rain
# 5       11.41       broken clouds
# 6        4.70                mist
# 7       17.11          few clouds
# 8        7.72     overcast clouds
# 9       14.99    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_sub_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]
